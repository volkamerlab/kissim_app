# %% [markdown]
# # Predict ligand profiling using `kissim` using the Davis dataset
#
# In order to assess the predictive power of `kissim`, we here choose a ligand-centric evaluation.
# We will compare if `kissim` can predict on- and off-targets determined in ligand profiling studies.
#
# - Kinase-kinase distance dataset (use KinMap kinase names): Select kinases from profiling dataset by query ligand
# - Kinase-ligand profiling dataset (use KinMap kinase names and PKIDB ligand names): Select kinases from distances dataset by the ligand's on-target
# - Merge both datasets and keep only kinases that have measurements in both datasets
# - Rank kinases by distances
# - Calculuate enrichment factors and enrichment plots
# - Calculate ROC curves

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

from src import data, evaluation

# %%
plt.style.use("seaborn")

# %% [markdown]
# ## Define parameters

# %%
# The only global that can be changed in this notebook
LIGAND_PROFILING_METHOD = "davis"

# %%
KINASE_DISTANCES_METHOD = "kissim"
KINASE_ACTIVITY_CUTOFF = 100
KINASE_ACTIVITY_MAX = True
MIN_N_SHARED_KINASES = 10
MIN_N_SHARED_ACTIVE_KINASES = 3

# %% [markdown]
# ## Kinase-kinase distances dataset
#
# __Criteria__:
#
# - Filters out kinases whose names cannot be mapped to KinMap kinase names.

# %%
# Full dataset (reported only, not further used)
kissim_df = data.distances.kissim(structure_kinase_mapping_by="minimum", kinmap_kinases=False)
print(f"Kinase distance matrix shape: {kissim_df.shape}")
# Out:
# Kinase distance matrix shape: (292, 292)

# %%
# Reduced dataset
kissim_df = data.distances.kissim(structure_kinase_mapping_by="minimum", kinmap_kinases=True)
print(f"Kinase distance matrix shape: {kissim_df.shape}")
kissim_df.iloc[:5, :5]
# Out:
# Changed kinase names (unknown names may be discarded - see function docstring):
#     kinase.input            kinase.kinmap
# 73         DCLK1                  DCAMKL1
# 133       JAK1-b                   JAK1_b
# 135       JAK2-b                   JAK2_b
# 176       MSK1-b                   MSK1_b
# 199       PI4K2A  unknown (not in KinMap)
# 200       PI4K2B  unknown (not in KinMap)
# 201        PI4KB  unknown (not in KinMap)
# 202       PIK3C3  unknown (not in KinMap)
# 236       RSK1-b                   RSK1_b
# 238       RSK2-b                   RSK2_b
# 267       TYK2-b                   TYK2_b
# 284        p110a  unknown (not in KinMap)
# 285        p110d  unknown (not in KinMap)
# 286        p110g  unknown (not in KinMap)
# Kinase distance matrix shape: (285, 285)
#            AAK1      ABL1      ABL2       ACK     ACTR2
# AAK1   0.000000  0.236804  0.247146  0.246718  0.258943
# ABL1   0.236804  0.000000  0.031895  0.135408  0.273800
# ABL2   0.247146  0.031895  0.000000  0.148168  0.294962
# ACK    0.246718  0.135408  0.148168  0.000000  0.294579
# ACTR2  0.258943  0.273800  0.294962  0.294579  0.000000

# %% [markdown]
# ## Kinase-ligand profiling dataset
#
# __Criteria__:
#
# - Load dataset with FDA-approved PKIDB ligands only.
# - Filters out ligands whose names cannot be mapped onto PKIDB ligand names.

# %%
# Full dataset (reported only, not further used)
profiling_df = data.profiling.load(LIGAND_PROFILING_METHOD)
print(f"Number of kinases (full dataset): {profiling_df.shape[0]}")
print(f"Number of ligands (full dataset): {profiling_df.shape[1]}")
# Out:
# Number of kinases (full dataset): 350
# Number of ligands (full dataset): 72

# %%
# Reduced dataset
profiling_df = data.profiling.load(LIGAND_PROFILING_METHOD, pkidb_ligands=True, fda_approved=True)
print(f"Number of kinases (FDA-approved PKIDB ligands only): {profiling_df.shape[0]}")
print(f"Number of ligands (FDA-approved PKIDB ligands only): {profiling_df.shape[1]}")
profiling_df.head()
# Out:
# Changed ligand names (unknown names may be discarded - see function docstring):
#          ligand.input            ligand.pkidb
# 0           TG-101348              Fedratinib
# 1           SB-203580  unknown (not in PKIDB)
# 3    CHIR-265/RAF-265  unknown (not in PKIDB)
# 4        AZD-1152HQPA  unknown (not in PKIDB)
# 5            MLN-8054  unknown (not in PKIDB)
# ..                ...                     ...
# 67          LY-333531           Ruboxistaurin
# 68            CI-1033              Canertinib
# 69  AZD-6244/ARRY-886  unknown (not in PKIDB)
# 70             PI-103  unknown (not in PKIDB)
# 71           AZD-2171               Cediranib
#
# [61 rows x 2 columns]
# Number of kinases (FDA-approved PKIDB ligands only): 350
# Number of ligands (FDA-approved PKIDB ligands only): 33
#       Fedratinib  Nilotinib  Axitinib  Midostaurin  Quizartinib  Linifanib  \
# AAK1        35.0        NaN    1200.0         48.0          NaN        NaN
# ABL1        44.0       13.0      36.0          NaN          NaN        NaN
# ABL2       570.0       26.0      70.0          NaN          NaN        NaN
# ALK2       150.0        NaN       NaN          NaN          NaN        NaN
# ALK4      6700.0        NaN       NaN          NaN          NaN        NaN
#
#       Neratinib  Masitinib  Brivanib  Vatalanib  ...  Pictilisib  Tandutinib  \
# AAK1        NaN        NaN       NaN        NaN  ...      9100.0         NaN
# ABL1        NaN       55.0     640.0        NaN  ...         NaN         NaN
# ABL2        NaN      110.0    1800.0        NaN  ...         NaN         NaN
# ALK2        NaN        NaN       NaN        NaN  ...         NaN      2500.0
# ALK4        NaN        NaN       NaN        NaN  ...         NaN         NaN
#
#       Sunitinib  Erlotinib  Imatinib  Bosutinib  Afatinib  Ruboxistaurin  \
# AAK1       11.0     1200.0       NaN   2300.000       NaN          900.0
# ABL1      150.0       76.0      21.0      0.057     570.0            NaN
# ABL2     1000.0      200.0      10.0      1.500       NaN            NaN
# ALK2        NaN        NaN       NaN        NaN       NaN            NaN
# ALK4        NaN        NaN       NaN        NaN       NaN            NaN
#
#       Canertinib  Cediranib
# AAK1         NaN        NaN
# ABL1        30.0       78.0
# ABL2       870.0      730.0
# ALK2      1700.0     3400.0
# ALK4         NaN     1500.0
#
# [5 rows x 33 columns]

# %%
profiling_df.count().sort_values().plot(kind="barh");

# %% [markdown]
# ### Ligands' on-targets dataset
#
# __Criteria__:
#
# - Filters out ligands that are not available in the PKIDB or have no targets in the PKIDB.
# - Filters out targets whose names cannot be mapped onto KinMap names

# %%
pd.set_option("max_colwidth", 100)
ligand_names = profiling_df.columns
ligand_targets = data.targets.pkidb(ligand_names, fda_approved=False)
ligand_targets
# Out:
# Changed kinase names (unknown names may be discarded - see function docstring):
#     kinase.input            kinase.kinmap
# 8            nan  unknown (not in KinMap)
# 10         CSF1R                      FMS
# 13         CSF1R                      FMS
# 15         ERBB2                    ErbB2
# 18        PDGFRA                   PDGFRa
# 19        PDGFRB                   PDGFRb
# 37        PDGFRA                   PDGFRa
# 38        PDGFRB                   PDGFRb
# 41        MAPK14                     p38a
# 43         ERBB2                    ErbB2
# 46         EPHA2                    EphA2
# 48          YES1                      YES
# 50        PDGFRB                   PDGFRb
# 53           nan  unknown (not in KinMap)
# 54        MAPK14                     p38a
# 55         VEGFA  unknown (not in KinMap)
# 57          PTK6                      BRK
# 58           TEK                     TIE2
# 65        PDGFRB                   PDGFRb
# 74        PDGFRA                   PDGFRa
# 75        PDGFRB                   PDGFRb
# 80        PIK3CA  unknown (not in KinMap)
# 81        PIK3CB  unknown (not in KinMap)
# 82        PIK3CD  unknown (not in KinMap)
# 83        PIK3CG  unknown (not in KinMap)
# 85         PDGFD  unknown (not in KinMap)
# 86        PDGFRB                   PDGFRb
# 92         CSF1R                      FMS
# 93        PDGFRA                   PDGFRa
# 95         NR1I2  unknown (not in KinMap)
# 98         NTRK1                     TRKA
# 99         CSF1R                      FMS
# 100       PDGFRA                   PDGFRa
# 103       PDGFRB                   PDGFRb
# 113       CAMK2G                   CaMK2g
# 115        ERBB2                    ErbB2
# 116        ERBB4                    ErbB4
# 117          nan  unknown (not in KinMap)
#     ligand.input  \
# 0   Lestaurtinib
# 1     Tandutinib
# 2       Brivanib
# 3     Canertinib
# 4      Cediranib
# 5    Doramapimod
# 6      Erlotinib
# 7      Gefitinib
# 8   Neflamapimod
# 9     Crizotinib
# 10     Nilotinib
# 11     Neratinib
# 12     Lapatinib
# 13   Quizartinib
# 14     Linifanib
# 15      Afatinib
# 16    Fedratinib
# 17      Axitinib
# 18     Vatalanib
# 19   Tofacitinib
# 20    Vandetanib
# 21     Masitinib
# 22     Motesanib
# 23      Imatinib
# 24     Sunitinib
# 25     Dasatinib
# 26     Pazopanib
# 27     Bosutinib
# 28     Sorafenib
#
#                                                        targets.pkidb  \
# 0                                                             [FLT3]
# 1                                                             [FLT3]
# 2                                                              [KDR]
# 3                                                             [EGFR]
# 4                                                              [KDR]
# 5                                                           [MAPK14]
# 6                                                             [EGFR]
# 7                                                             [EGFR]
# 8                                                           [MAPK14]
# 9                                                         [ALK, MET]
# 10                                                       [ABL1, KIT]
# 11                                                     [ERBB2, EGFR]
# 12                                                     [EGFR, ERBB2]
# 13                                                [FLT3, CSF1R, KIT]
# 14                                                [FLT3, CSF1R, KDR]
# 15                                              [EGFR, ERBB2, ERBB4]
# 16                                                [JAK2, FLT3, BRD4]
# 17                                                 [FLT1, KDR, FLT4]
# 18                                                 [FLT1, KDR, FLT4]
# 19                                          [JAK1, JAK2, JAK3, TYK2]
# 20                                            [EGFR, PTK6, TEK, RET]
# 21                        [KIT, PDGFRA, PDGFRB, FGFR1, FGFR2, FGFR3]
# 22                       [FLT1, KDR, FLT4, PDGFRA, PDGFRB, KIT, RET]
# 23              [KIT, RET, NTRK1, CSF1R, PDGFRA, DDR1, ABL1, PDGFRB]
# 24               [PDGFRB, FLT1, KIT, KDR, FLT4, FLT3, CSF1R, PDGFRA]
# 25             [ABL1, SRC, EPHA2, LCK, YES1, KIT, PDGFRB, ABL2, FYN]
# 26         [FLT1, KDR, FLT4, PDGFRA, PDGFRB, KIT, FGFR3, ITK, FGFR1]
# 27  [BCR, ABL1, LYN, HCK, SRC, CDK2, MAP2K1, MAP2K2, MAP3K2, CAMK2G]
# 28      [BRAF, RAF1, FLT4, KDR, FLT3, PDGFRB, KIT, FGFR1, RET, FLT1]
#
#                                                       targets.kinmap
# 0                                                             [FLT3]
# 1                                                             [FLT3]
# 2                                                              [KDR]
# 3                                                             [EGFR]
# 4                                                              [KDR]
# 5                                                             [p38a]
# 6                                                             [EGFR]
# 7                                                             [EGFR]
# 8                                                             [p38a]
# 9                                                         [ALK, MET]
# 10                                                       [ABL1, KIT]
# 11                                                     [ErbB2, EGFR]
# 12                                                     [EGFR, ErbB2]
# 13                                                  [FLT3, FMS, KIT]
# 14                                                  [FLT3, FMS, KDR]
# 15                                              [EGFR, ErbB2, ErbB4]
# 16                                                [JAK2, FLT3, BRD4]
# 17                                                 [FLT1, KDR, FLT4]
# 18                                                 [FLT1, KDR, FLT4]
# 19                                          [JAK1, JAK2, JAK3, TYK2]
# 20                                            [EGFR, BRK, TIE2, RET]
# 21                        [KIT, PDGFRa, PDGFRb, FGFR1, FGFR2, FGFR3]
# 22                       [FLT1, KDR, FLT4, PDGFRa, PDGFRb, KIT, RET]
# 23                 [KIT, RET, TRKA, FMS, PDGFRa, DDR1, ABL1, PDGFRb]
# 24                 [PDGFRb, FLT1, KIT, KDR, FLT4, FLT3, FMS, PDGFRa]
# 25              [ABL1, SRC, EphA2, LCK, YES, KIT, PDGFRb, ABL2, FYN]
# 26         [FLT1, KDR, FLT4, PDGFRa, PDGFRb, KIT, FGFR3, ITK, FGFR1]
# 27  [BCR, ABL1, LYN, HCK, SRC, CDK2, MAP2K1, MAP2K2, MAP3K2, CaMK2g]
# 28      [BRAF, RAF1, FLT4, KDR, FLT3, PDGFRb, KIT, FGFR1, RET, FLT1]

# %% [markdown]
# ### Ligand-kinase datasets
#
# We merge now profiling and kinase similarity information into one dataset per ligand-kinase pair (_ligand-kinase dataset_).
#
# We only keep ligand-kinase pairs that
# - have a minimum of `MIN_N_SHARED_KINASES` shared kinases
# - have a minimum of `MIN_N_SHARED_ACTIVE_KINASES` shared active kinases, while activity is defined <= `KINASE_ACTIVITY_CUTOFF`

# %% [markdown]
# Select ligand-kinase pairs with enough coverage.

# %%
ligand_kinase_pairs = (
    ligand_targets[["ligand.input", "targets.kinmap"]]
    .explode("targets.kinmap")
    .to_numpy()
    .tolist()
)

# %% [markdown]
# ## Evaluation metrics

# %%
evaluator = evaluation.LigandVsKinaseEvaluator(
    ligand_kinase_pairs,
    LIGAND_PROFILING_METHOD,
    KINASE_DISTANCES_METHOD,
    KINASE_ACTIVITY_CUTOFF,
    KINASE_ACTIVITY_MAX,
    MIN_N_SHARED_KINASES,
    MIN_N_SHARED_ACTIVE_KINASES,
)
# Out:
# Changed ligand names (unknown names may be discarded - see function docstring):
#          ligand.input            ligand.pkidb
# 0           TG-101348              Fedratinib
# 1           SB-203580  unknown (not in PKIDB)
# 3    CHIR-265/RAF-265  unknown (not in PKIDB)
# 4        AZD-1152HQPA  unknown (not in PKIDB)
# 5            MLN-8054  unknown (not in PKIDB)
# ..                ...                     ...
# 67          LY-333531           Ruboxistaurin
# 68            CI-1033              Canertinib
# 69  AZD-6244/ARRY-886  unknown (not in PKIDB)
# 70             PI-103  unknown (not in PKIDB)
# 71           AZD-2171               Cediranib
#
# [61 rows x 2 columns]

# %%
pkidb = data.ligands.pkidb()
ligands = pkidb.set_index("ID")["Type"][list(evaluator.data_dict.keys())].reset_index()
ligands
# Out:
#               ID Type
# 0   Lestaurtinib  nan
# 1     Tandutinib  nan
# 2       Brivanib  nan
# 3     Canertinib  nan
# 4      Cediranib  nan
# 5    Doramapimod    2
# 6      Erlotinib  1.5
# 7      Gefitinib  1.5
# 8   Neflamapimod  nan
# 9     Crizotinib    1
# 10     Nilotinib    2
# 11     Neratinib  nan
# 12     Lapatinib  1.5
# 13   Quizartinib    2
# 14     Linifanib  nan
# 15      Afatinib    1
# 16    Fedratinib  nan
# 17      Axitinib    2
# 18     Vatalanib  nan
# 19   Tofacitinib    1
# 20    Vandetanib  1.5
# 21     Masitinib  nan
# 22     Motesanib    2
# 23      Imatinib    2
# 24     Sunitinib    1
# 25     Dasatinib    1
# 26     Pazopanib    1
# 27     Bosutinib    1
# 28     Sorafenib    2

# %% [markdown]
# ### Enrichment
#
# #### Enrichment factor
#
# An enrichment factor is calculated as follows:
#
# $EF_{x\%} = \frac{\frac{n_s}{n}}{\frac{N_s}{N}}$
#
# with
#
# - $N$   : Number of kinases in total
# - $N_s$ : Number of kinases in top x% of ranked kinases
# - $n$   : Number of active kinases in total
# - $n_s$ : Number of active kinases in top x% of ranked kinases

# %%
evaluator.plot_enrichment_factors()

# %% [markdown]
# #### Enrichment plots
#
# For an enrichment plot, the x and y values are calculated as follows:
#
# $x = \frac{N_s}{N}$, $y = \frac{n_s}{n}$
#
# with
#
# - $N$   : Number of kinases in total
# - $N_s$ : Number of kinases in top x% of ranked kinases
# - $n$   : Number of active kinases in total
# - $n_s$ : Number of active kinases in top x% of ranked kinases

# %%
evaluator.plot_enrichment()

# %% [markdown]
# ### ROC curves
#
# - $TPR = \frac{TP}{P} = \frac{TP}{TP + FN}$
# - $FPR = \frac{FP}{N} = \frac{FP}{FP + TN}$

# %%
evaluator.plot_roc_curves();
