# %% [markdown]
# # Performance summary over different `kissim` setups
#
# Summarize performance of different `kissim` setups:
#
# - Profiling vs. `kissim` AUCs: How well does `kissim` reflect profiling data?
# - Phylogenetic `kissim` tree: How well do selected on- and off-targets cluster together?
# - Top `kissim` ranks: How high do selected on- and off-targets rank in `kissim`?
#
# DFG-in conformations only!

# %%
from pathlib import Path

import pandas as pd
import seaborn as sns
from Bio import Phylo

# %%
cm = sns.light_palette("blue", as_cmap=True)

# %%
HERE = Path(_dh[-1])  # noqa: F821
RESULTS = HERE / "../../results"

# %% [markdown]
# ## `kissim` setups

# %%
DATA_SUBSET = [
    "dfg_in",
]
WEIGHTING_SCHEMES = ["15", "110", "101", "100"]
CLUSTERING_METHODS = ["ward", "average", "weighted"]

# %%
ON_OFF_PAIRS = [
    ["EGFR", ["SLK", "LOK", "GAK"]],  # Erlotinib
    ["SLK", ["LOK"]],  # Erlotinib
    ["DRAK2", ["CaMKK2"]],
    ["ABL2", ["AurA"]],  # VX-680/MK-0457
    ["ABL1", ["GAK"]],  # Dasatinib
    ["GAK", ["DAPK3"]],  # Inrebic
    ["AurC", ["KIT"]],  # Inlyta
    ["KIT", ["AMPKa2", "FMS"]],  # JNJ-28312141
    ["ABL1", ["BMPR1B"]]  # PD-173955
]

# %% [markdown]
# ## Profiling vs. `kissim` AUCs

# %%
auc_dfs = {}
mean_df = []
median_df = []
std_df = []
for data_subset in DATA_SUBSET:
    path = RESULTS / data_subset
    auc_df = pd.read_csv(path / "auc.csv")
    auc_dfs[data_subset] = auc_df[["15", "100", "110", "101", "111"]]

    mean = auc_dfs[data_subset].describe().loc["mean", :]
    mean.name = data_subset
    mean_df.append(mean)

    median = auc_dfs[data_subset].describe().loc["50%", :]
    median.name = data_subset
    median_df.append(median)

    std = auc_dfs[data_subset].describe().loc["std", :]
    std.name = data_subset
    std_df.append(std)
mean_df = pd.concat(mean_df, axis=1)
median_df = pd.concat(median_df, axis=1)
std_df = pd.concat(std_df, axis=1)

# %% [markdown]
# ### Mean

# %%
mean_df.style.background_gradient(cmap=cm, axis=None)
# Out:
# <style  type="text/css" >
# #T_933c7_row0_col0{
#             background-color:  #6666fa;
#             color:  #000000;
#         }#T_933c7_row1_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_933c7_row2_col0{
#             background-color:  #3333fc;
#             color:  #f1f1f1;
#         }#T_933c7_row3_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_933c7_row4_col0{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }</style><table id="T_933c7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_933c7_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_933c7_row0_col0" class="data row0 col0" >0.728380</td>
#             </tr>
#             <tr>
#                         <th id="T_933c7_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_933c7_row1_col0" class="data row1 col0" >0.734528</td>
#             </tr>
#             <tr>
#                         <th id="T_933c7_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_933c7_row2_col0" class="data row2 col0" >0.731435</td>
#             </tr>
#             <tr>
#                         <th id="T_933c7_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_933c7_row3_col0" class="data row3 col0" >0.719981</td>
#             </tr>
#             <tr>
#                         <th id="T_933c7_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_933c7_row4_col0" class="data row4 col0" >0.721580</td>
#             </tr>
#     </tbody></table>

# %%
mean_df.style.highlight_max(axis=None, color="yellow")
# Out:
# <style  type="text/css" >
# #T_d14e6_row1_col0{
#             background-color:  yellow;
#         }</style><table id="T_d14e6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d14e6_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_d14e6_row0_col0" class="data row0 col0" >0.728380</td>
#             </tr>
#             <tr>
#                         <th id="T_d14e6_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_d14e6_row1_col0" class="data row1 col0" >0.734528</td>
#             </tr>
#             <tr>
#                         <th id="T_d14e6_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_d14e6_row2_col0" class="data row2 col0" >0.731435</td>
#             </tr>
#             <tr>
#                         <th id="T_d14e6_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_d14e6_row3_col0" class="data row3 col0" >0.719981</td>
#             </tr>
#             <tr>
#                         <th id="T_d14e6_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_d14e6_row4_col0" class="data row4 col0" >0.721580</td>
#             </tr>
#     </tbody></table>

# %%
mean_df.style.highlight_max(axis=0, color="yellow")
# Out:
# <style  type="text/css" >
# #T_cf6fe_row1_col0{
#             background-color:  yellow;
#         }</style><table id="T_cf6fe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf6fe_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_cf6fe_row0_col0" class="data row0 col0" >0.728380</td>
#             </tr>
#             <tr>
#                         <th id="T_cf6fe_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_cf6fe_row1_col0" class="data row1 col0" >0.734528</td>
#             </tr>
#             <tr>
#                         <th id="T_cf6fe_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_cf6fe_row2_col0" class="data row2 col0" >0.731435</td>
#             </tr>
#             <tr>
#                         <th id="T_cf6fe_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_cf6fe_row3_col0" class="data row3 col0" >0.719981</td>
#             </tr>
#             <tr>
#                         <th id="T_cf6fe_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_cf6fe_row4_col0" class="data row4 col0" >0.721580</td>
#             </tr>
#     </tbody></table>

# %%
mean_df.style.highlight_max(axis=1, color="yellow")
# Out:
# <style  type="text/css" >
# #T_da7d2_row0_col0,#T_da7d2_row1_col0,#T_da7d2_row2_col0,#T_da7d2_row3_col0,#T_da7d2_row4_col0{
#             background-color:  yellow;
#         }</style><table id="T_da7d2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da7d2_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_da7d2_row0_col0" class="data row0 col0" >0.728380</td>
#             </tr>
#             <tr>
#                         <th id="T_da7d2_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_da7d2_row1_col0" class="data row1 col0" >0.734528</td>
#             </tr>
#             <tr>
#                         <th id="T_da7d2_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_da7d2_row2_col0" class="data row2 col0" >0.731435</td>
#             </tr>
#             <tr>
#                         <th id="T_da7d2_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_da7d2_row3_col0" class="data row3 col0" >0.719981</td>
#             </tr>
#             <tr>
#                         <th id="T_da7d2_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_da7d2_row4_col0" class="data row4 col0" >0.721580</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Median

# %%
median_df.style.background_gradient(cmap=cm, axis=None)
# Out:
# <style  type="text/css" >
# #T_823fc_row0_col0{
#             background-color:  #9090f8;
#             color:  #000000;
#         }#T_823fc_row1_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_823fc_row2_col0{
#             background-color:  #2727fd;
#             color:  #f1f1f1;
#         }#T_823fc_row3_col0{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_823fc_row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }</style><table id="T_823fc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_823fc_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_823fc_row0_col0" class="data row0 col0" >0.762898</td>
#             </tr>
#             <tr>
#                         <th id="T_823fc_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_823fc_row1_col0" class="data row1 col0" >0.782162</td>
#             </tr>
#             <tr>
#                         <th id="T_823fc_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_823fc_row2_col0" class="data row2 col0" >0.776949</td>
#             </tr>
#             <tr>
#                         <th id="T_823fc_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_823fc_row3_col0" class="data row3 col0" >0.757967</td>
#             </tr>
#             <tr>
#                         <th id="T_823fc_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_823fc_row4_col0" class="data row4 col0" >0.750000</td>
#             </tr>
#     </tbody></table>

# %%
median_df.style.highlight_max(axis=None, color="yellow")
# Out:
# <style  type="text/css" >
# #T_ff58f_row1_col0{
#             background-color:  yellow;
#         }</style><table id="T_ff58f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff58f_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_ff58f_row0_col0" class="data row0 col0" >0.762898</td>
#             </tr>
#             <tr>
#                         <th id="T_ff58f_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_ff58f_row1_col0" class="data row1 col0" >0.782162</td>
#             </tr>
#             <tr>
#                         <th id="T_ff58f_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_ff58f_row2_col0" class="data row2 col0" >0.776949</td>
#             </tr>
#             <tr>
#                         <th id="T_ff58f_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_ff58f_row3_col0" class="data row3 col0" >0.757967</td>
#             </tr>
#             <tr>
#                         <th id="T_ff58f_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_ff58f_row4_col0" class="data row4 col0" >0.750000</td>
#             </tr>
#     </tbody></table>

# %%
median_df.style.highlight_max(axis=1, color="yellow")
# Out:
# <style  type="text/css" >
# #T_9f26a_row0_col0,#T_9f26a_row1_col0,#T_9f26a_row2_col0,#T_9f26a_row3_col0,#T_9f26a_row4_col0{
#             background-color:  yellow;
#         }</style><table id="T_9f26a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f26a_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_9f26a_row0_col0" class="data row0 col0" >0.762898</td>
#             </tr>
#             <tr>
#                         <th id="T_9f26a_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_9f26a_row1_col0" class="data row1 col0" >0.782162</td>
#             </tr>
#             <tr>
#                         <th id="T_9f26a_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_9f26a_row2_col0" class="data row2 col0" >0.776949</td>
#             </tr>
#             <tr>
#                         <th id="T_9f26a_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_9f26a_row3_col0" class="data row3 col0" >0.757967</td>
#             </tr>
#             <tr>
#                         <th id="T_9f26a_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_9f26a_row4_col0" class="data row4 col0" >0.750000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Standard deviation

# %%
std_df.style.background_gradient(cmap=cm, axis=None)
# Out:
# <style  type="text/css" >
# #T_13f0c_row0_col0{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_13f0c_row1_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_13f0c_row2_col0{
#             background-color:  #1111fe;
#             color:  #f1f1f1;
#         }#T_13f0c_row3_col0,#T_13f0c_row4_col0{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }</style><table id="T_13f0c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13f0c_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_13f0c_row0_col0" class="data row0 col0" >0.137739</td>
#             </tr>
#             <tr>
#                         <th id="T_13f0c_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_13f0c_row1_col0" class="data row1 col0" >0.144999</td>
#             </tr>
#             <tr>
#                         <th id="T_13f0c_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_13f0c_row2_col0" class="data row2 col0" >0.144183</td>
#             </tr>
#             <tr>
#                         <th id="T_13f0c_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_13f0c_row3_col0" class="data row3 col0" >0.133896</td>
#             </tr>
#             <tr>
#                         <th id="T_13f0c_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_13f0c_row4_col0" class="data row4 col0" >0.133874</td>
#             </tr>
#     </tbody></table>

# %%
std_df.style.highlight_max(axis=None, color="yellow")
# Out:
# <style  type="text/css" >
# #T_07e77_row1_col0{
#             background-color:  yellow;
#         }</style><table id="T_07e77_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_07e77_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_07e77_row0_col0" class="data row0 col0" >0.137739</td>
#             </tr>
#             <tr>
#                         <th id="T_07e77_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_07e77_row1_col0" class="data row1 col0" >0.144999</td>
#             </tr>
#             <tr>
#                         <th id="T_07e77_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_07e77_row2_col0" class="data row2 col0" >0.144183</td>
#             </tr>
#             <tr>
#                         <th id="T_07e77_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_07e77_row3_col0" class="data row3 col0" >0.133896</td>
#             </tr>
#             <tr>
#                         <th id="T_07e77_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_07e77_row4_col0" class="data row4 col0" >0.133874</td>
#             </tr>
#     </tbody></table>

# %%
std_df.style.highlight_max(axis=0, color="yellow")
# Out:
# <style  type="text/css" >
# #T_d3286_row1_col0{
#             background-color:  yellow;
#         }</style><table id="T_d3286_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3286_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_d3286_row0_col0" class="data row0 col0" >0.137739</td>
#             </tr>
#             <tr>
#                         <th id="T_d3286_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_d3286_row1_col0" class="data row1 col0" >0.144999</td>
#             </tr>
#             <tr>
#                         <th id="T_d3286_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_d3286_row2_col0" class="data row2 col0" >0.144183</td>
#             </tr>
#             <tr>
#                         <th id="T_d3286_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_d3286_row3_col0" class="data row3 col0" >0.133896</td>
#             </tr>
#             <tr>
#                         <th id="T_d3286_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_d3286_row4_col0" class="data row4 col0" >0.133874</td>
#             </tr>
#     </tbody></table>

# %%
std_df.style.highlight_max(axis=1, color="yellow")
# Out:
# <style  type="text/css" >
# #T_0f10c_row0_col0,#T_0f10c_row1_col0,#T_0f10c_row2_col0,#T_0f10c_row3_col0,#T_0f10c_row4_col0{
#             background-color:  yellow;
#         }</style><table id="T_0f10c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dfg_in</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f10c_level0_row0" class="row_heading level0 row0" >15</th>
#                         <td id="T_0f10c_row0_col0" class="data row0 col0" >0.137739</td>
#             </tr>
#             <tr>
#                         <th id="T_0f10c_level0_row1" class="row_heading level0 row1" >100</th>
#                         <td id="T_0f10c_row1_col0" class="data row1 col0" >0.144999</td>
#             </tr>
#             <tr>
#                         <th id="T_0f10c_level0_row2" class="row_heading level0 row2" >110</th>
#                         <td id="T_0f10c_row2_col0" class="data row2 col0" >0.144183</td>
#             </tr>
#             <tr>
#                         <th id="T_0f10c_level0_row3" class="row_heading level0 row3" >101</th>
#                         <td id="T_0f10c_row3_col0" class="data row3 col0" >0.133896</td>
#             </tr>
#             <tr>
#                         <th id="T_0f10c_level0_row4" class="row_heading level0 row4" >111</th>
#                         <td id="T_0f10c_row4_col0" class="data row4 col0" >0.133874</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Top `kissim` ranks

# %%
def get_ranks(distance_matrix, rank_from, rank_to):
    """
    Get ranks for all kinases w.r.t. to a query kinase.
    """

    ranks = pd.concat(
        [
            distance_matrix[rank_from].sort_values(),
            distance_matrix[rank_from].sort_values().rank(),
        ],
        axis=1,
    )
    ranks.columns = ["distance", "rank"]
    if rank_to is not None:
        ranks = ranks.loc[rank_to, :]
    pair_names = [f"{rank_from}-{rank_to}" for i in rank_to]
    return ranks, pair_names

# %%
# %%time

results_list = []

for data_subset in DATA_SUBSET:
    for weighting in WEIGHTING_SCHEMES:
        results = []
        columns = []
        results.extend([data_subset, weighting])

        kinase_matrix_path = RESULTS / f"{data_subset}/fingerprint_distances_to_kinase_matrix.csv"
        kinase_matrix = pd.read_csv(kinase_matrix_path, index_col=0)

        for pair in ON_OFF_PAIRS:
            ranks, pair_names = get_ranks(kinase_matrix, pair[0], pair[1])
            results.extend(ranks["rank"].to_list())

        results_list.append(results)
# Out:
# CPU times: user 119 ms, sys: 8.01 ms, total: 127 ms
# Wall time: 126 ms

# %%
matrix_ranks_df = pd.DataFrame(
    results_list,
    columns=["subset", "weighting"] + [f"{i[0]}-{j}" for i in ON_OFF_PAIRS for j in i[1]]
)
matrix_ranks_df = matrix_ranks_df.set_index(["subset", "weighting"])
cm = sns.light_palette("blue", as_cmap=True, reverse=True)

# %%
matrix_ranks_df.style.applymap(lambda x: "background-color : yellow" if x < 25 else "")
000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_f37b6_level1_row2" class="row_heading level1 row2" >101</th>
#                         <td id="T_f37b6_row2_col0" class="data row2 col0" >42.000000</td>
#                         <td id="T_f37b6_row2_col1" class="data row2 col1" >27.000000</td>
#                         <td id="T_f37b6_row2_col2" class="data row2 col2" >181.000000</td>
#                         <td id="T_f37b6_row2_col3" class="data row2 col3" >2.000000</td>
#                         <td id="T_f37b6_row2_col4" class="data row2 col4" >5.000000</td>
#                         <td id="T_f37b6_row2_col5" class="data row2 col5" >90.000000</td>
#                         <td id="T_f37b6_row2_col6" class="data row2 col6" >120.000000</td>
#                         <td id="T_f37b6_row2_col7" class="data row2 col7" >10.000000</td>
#                         <td id="T_f37b6_row2_col8" class="data row2 col8" >196.000000</td>
#                         <td id="T_f37b6_row2_col9" class="data row2 col9" >82.000000</td>
#                         <td id="T_f37b6_row2_col10" class="data row2 col10" >2.000000</td>
#                         <td id="T_f37b6_row2_col11" class="data row2 col11" >227.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_f37b6_level1_row3" class="row_heading level1 row3" >100</th>
#                         <td id="T_f37b6_row3_col0" class="data row3 col0" >42.000000</td>
#                         <td id="T_f37b6_row3_col1" class="data row3 col1" >27.000000</td>
#                         <td id="T_f37b6_row3_col2" class="data row3 col2" >181.000000</td>
#                         <td id="T_f37b6_row3_col3" class="data row3 col3" >2.000000</td>
#                         <td id="T_f37b6_row3_col4" class="data row3 col4" >5.000000</td>
#                         <td id="T_f37b6_row3_col5" class="data row3 col5" >90.000000</td>
#                         <td id="T_f37b6_row3_col6" class="data row3 col6" >120.000000</td>
#                         <td id="T_f37b6_row3_col7" class="data row3 col7" >10.000000</td>
#                         <td id="T_f37b6_row3_col8" class="data row3 col8" >196.000000</td>
#                         <td id="T_f37b6_row3_col9" class="data row3 col9" >82.000000</td>
#                         <td id="T_f37b6

# %% [markdown]
# ## Ranks

# %%
from kissim.comparison import FingerprintDistanceGenerator
from src.definitions import COVERAGE_CUTOFF

# %%
fingerprint_distances = FingerprintDistanceGenerator.from_csv(
    RESULTS / f"{DATA_SUBSET[0]}/fingerprint_distances.csv"
)

# %%
kinase_matrix = fingerprint_distances.kinase_distance_matrix(coverage_min=COVERAGE_CUTOFF)

# %%
kinase_matrix[["EGFR"]]
# Out:
# kinase.2      EGFR
# kinase.1
# AAK1      0.113051
# ABL1      0.064218
# ABL2      0.067813
# ACK       0.067122
# ACTR2     0.124454
# ...            ...
# p38a      0.092515
# p38b      0.096663
# p38d      0.101985
# p38g      0.095345
# p70S6K    0.094461
#
# [257 rows x 1 columns]

# %%
from opencadd.databases.klifs import setup_remote

# %%
klifs_session = setup_remote()

kinase_names = kinase_matrix["EGFR"].index.to_list()
kinase_groups = klifs_session.kinases.by_kinase_name(
    kinase_names, species="Human"
)[["kinase.klifs_name", "kinase.group"]]
kinase_groups = kinase_groups.set_index("kinase.klifs_name").squeeze()

kinase_ranks = kinase_matrix["EGFR"]
kinase_ranks.name = "ranks"
kinase_ranks.index.name = "kinase.klifs_name"

kinase_ranks = pd.merge(kinase_groups, kinase_ranks, left_index=True, right_index=True).reset_index()

# %%
kinase_ranks.sort_values("ranks").head(50)
# Out:
#     kinase.klifs_name kinase.group     ranks
# 86               EGFR           TK  0.000000
# 76              ErbB4           TK  0.025807
# 88              ErbB2           TK  0.040656
# 89              ErbB3           TK  0.048027
# 126               SYK           TK  0.054085
# 92              FGFR4           TK  0.062642
# 115               RET           TK  0.062651
# 185               BTK           TK  0.062941
# 167              ABL1           TK  0.064218
# 192             IGF1R           TK  0.066139
# 120               ITK           TK  0.066302
# 219               ALK           TK  0.066779
# 93               INSR           TK  0.066821
# 175             EphB1           TK  0.066972
# 117               ACK           TK  0.067122
# 156             ZAP70           TK  0.067479
# 168              ABL2           TK  0.067813
# 90              FGFR2           TK  0.067817
# 91              FGFR3           TK  0.070113
# 109               KDR           TK  0.070229
# 238               ROS           TK  0.070722
# 127              TIE2           TK  0.070940
# 189             EphA2           TK  0.071143
# 73              EphA3           TK  0.071199
# 206               RON           TK  0.071302
# 77              FGFR1           TK  0.071418
# 222               LOK          STE  0.071987
# 135               FAK           TK  0.072031
# 143               FES           TK  0.072712
# 145               HCK           TK  0.072834
# 136               BRK           TK  0.072899
# 98                MER           TK  0.073480
# 94               JAK3           TK  0.073696
# 147               LYN           TK  0.074218
# 105               FMS           TK  0.074323
# 146              JAK2           TK  0.074467
# 191             EphB4           TK  0.074869
# 75              EphB2           TK  0.075697
# 213               LCK           TK  0.075903
# 87              EphA7           TK  0.076296
# 196               MET           TK  0.076932
# 140               SLK          STE  0.077030
# 179               SRC           TK  0.077367
# 108              JAK1           TK  0.078250
# 74              EphA5           TK  0.078287
# 114              PYK2           TK  0.078318
# 103               AXL           TK  0.078978
# 235               FYN           TK  0.079652
# 232               CSK           TK  0.079747
# 190             EphA8           TK  0.079759

# %% [markdown]
# ## Phylogenetic `kissim` tree

# %%
import itertools
import numpy as np

# %%
def pairs_to_symmetric_matrix(pairs):
    """
    Create symmetric matrix with diagonal of 0.0 from pair combinations.
    """
    
    pairs1 = pd.DataFrame(pairs)
    pairs2 = pairs1[[1, 0, 2]]
    pairs2.columns = [0, 1, 2]
    pairs_all = pd.concat([pairs1, pairs2])
    matrix = pairs_all.pivot(index=0, columns=1, values=2)
    np.fill_diagonal(matrix.values, 0.0)
    symmetic_matrix = pd.DataFrame(matrix.values, columns=matrix.columns, index=matrix.index)
    return symmetic_matrix

# %%
def get_tree_distance_matrix(tree):
    """
    Get a matrix of all-against-all kinase distances in the kinase tree.
    """

    kinases = [clade.name for clade in tree.get_terminals()]
    kinase_pairs = itertools.combinations(kinases, 2)

    kinase_pairs_tree_distances = []

    for kinase1, kinase2 in kinase_pairs:
        kinase_pairs_tree_distances.append([kinase1, kinase2, tree.distance(kinase1, kinase2)])

    tree_distance_matrix = pairs_to_symmetric_matrix(kinase_pairs_tree_distances)

    return tree_distance_matrix

# %%
# %%time

results_list = []

for data_subset in DATA_SUBSET:
    print(data_subset)
    for weighting in WEIGHTING_SCHEMES:
        for cmethod in CLUSTERING_METHODS:
            results = []
            results.extend([data_subset, weighting, cmethod])

            tree_path = RESULTS / f"{data_subset}/trees/tree_0.8_{weighting}_{cmethod}.tree"
            kissim_tree = Phylo.read(tree_path, "newick")
            tree_distance_matrix = get_tree_distance_matrix(kissim_tree)
            
            for pair in ON_OFF_PAIRS:
                ranks, pair_names = get_ranks(tree_distance_matrix, pair[0], pair[1])
                results.extend(ranks["rank"].to_list())

            results_list.append(results)
# Out:
# dfg_in
# CPU times: user 2min 11s, sys: 4.12 ms, total: 2min 11s
# Wall time: 2min 11s

# %%
tree_ranks_df = pd.DataFrame(
    results_list,
    columns=["subset", "weighting", "cmethod"] + [f"{i[0]}-{j}" for i in ON_OFF_PAIRS for j in i[1]]
)
tree_ranks_df = tree_ranks_df.set_index(["subset", "weighting", "cmethod"])
cm = sns.light_palette("blue", as_cmap=True, reverse=True)

# %%
tree_ranks_df.style.applymap(lambda x: "background-color : yellow" if x < 25 else "")
# Out:
# <style  type="text/css" >
# #T_8f803_row0_col3,#T_8f803_row0_col4,#T_8f803_row0_col10,#T_8f803_row1_col3,#T_8f803_row1_col4,#T_8f803_row1_col10,#T_8f803_row2_col3,#T_8f803_row2_col4,#T_8f803_row2_col10,#T_8f803_row3_col3,#T_8f803_row3_col4,#T_8f803_row3_col10,#T_8f803_row4_col3,#T_8f803_row4_col4,#T_8f803_row4_col10,#T_8f803_row5_col3,#T_8f803_row5_col4,#T_8f803_row5_col7,#T_8f803_row5_col10,#T_8f803_row6_col3,#T_8f803_row6_col4,#T_8f803_row6_col10,#T_8f803_row7_col3,#T_8f803_row7_col4,#T_8f803_row7_col10,#T_8f803_row8_col3,#T_8f803_row8_col4,#T_8f803_row8_col7,#T_8f803_row8_col10,#T_8f803_row9_col3,#T_8f803_row9_col4,#T_8f803_row9_col10,#T_8f803_row10_col3,#T_8f803_row10_col4,#T_8f803_row10_col7,#T_8f803_row10_col10,#T_8f803_row11_col3,#T_8f803_row11_col4,#T_8f803_row11_col10{
#             background-color :  yellow;
#         }</style><table id="T_8f803_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EGFR-SLK</th>        <th class="col_heading level0 col1" >EGFR-LOK</th>        <th class="col_heading level0 col2" >EGFR-GAK</th>        <th class="col_heading level0 col3" >SLK-LOK</th>        <th class="col_heading level0 col4" >DRAK2-CaMKK2</th>        <th class="col_heading level0 col5" >ABL2-AurA</th>        <th class="col_heading level0 col6" >ABL1-GAK</th>        <th class="col_heading level0 col7" >GAK-DAPK3</th>        <th class="col_heading level0 col8" >AurC-KIT</th>        <th class="col_heading level0 col9" >KIT-AMPKa2</th>        <th class="col_heading level0 col10" >KIT-FMS</th>        <th class="col_heading level0 col11" >ABL1-BMPR1B</th>    </tr>    <tr>        <th class="index_name level0" >subset</th>        <th class="index_name level1" >weighting</th>        <th class="index_name level2" >cmethod</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f803_level0_row0" class="row_heading level0 row0" rowspan="12">dfg_in</th>
#                         <th id="T_8f803_level1_row0" class="row_heading level1 row0" rowspan="3">15</th>
#                         <th id="T_8f803_level2_row0" class="row_heading level2 row0" >ward</th>
#                         <td id="T_8f803_row0_col0" class="data row0 col0" >93.000000</td>
#                         <td id="T_8f803_row0_col1" class="data row0 col1" >93.000000</td>
#                         <td id="T_8f803_row0_col2" class="data row0 col2" >55.000000</td>
#                         <td id="T_8f803_row0_col3" class="data row0 col3" >2.000000</td>
#                         <td id="T_8f803_row0_col4" class="data row0 col4" >7.000000</td>
#                         <td id="T_8f803_row0_col5" class="data row0 col5" >55.000000</td>
#                         <td id="T_8f803_row0_col6" class="data row0 col6" >55.000000</td>
#                         <td id="T_8f803_row0_col7" class="data row0 col7" >128.000000</td>
#                         <td id="T_8f803_row0_col8" class="data row0 col8" >208.000000</td>
#                         <td id="T_8f803_row0_col9" class="data row0 col9" >227.500000</td>
#                         <td id="T_8f803_row0_col10" class="data row0 col10" >2.000000</td>
#                         <td id="T_8f803_row0_col11" class="data row0 col11" >51.500000</td>
#             </tr>
#             <tr>
#                                         <th id="T_8f803_level2_row1" class="row_heading level2 row1" >average</th>
#                         <td id="T_8f803_row1_col0" class="data row1 col0" >103.500000</td>
#                         <td id="T_8f803_row1_col1" class="data row1 col1" >103.500000</td>
#                         <td id="T_8f803_row1_col2" class="data row1 col2" >180.000000</td>
#                         <td id="T_8f803_row1_col3" class="data row1 col3" >2.000000</td>
#                         <td id="T_8f803_row1_col4" class="data row1 col4" >11.000000</td>
#                         <td id="T_8f803_row1_col5" class="data row1 col5" >58.000000</td>
#                         <td id="T_8f803_row1_col6" class="data row1 col6" >180.000000</td>
#                         <td id="T_8f803_row1_col7" class="data row1 col7" >169.000000</td>
#                         <td id="T_8f803_row1_col8" class="data row1 col8" >121.500000</td>
#                         <td id="T_8f803_row1_col9" class="data row1 col9" >103.500000</td>
#                         <td id="T_8f803_row1_col10" class="data row1 col10" >2.000000</td>
#                         <td id="T_8f803_row1_col11" class="data row1 col11" >221.000000</td>
#             </tr>
#             <tr>
#                                         <th id="T_8f803_level2_row2" class="row_heading level2 row2" >weighted</th>
#                         <td id="T_8f803_row2_col0" class="data row2 col0" >128.500000</td>
#                         <td id="T_8f803_row2_col1" class="data row2 col1" >128.500000</td>
#                         <td id="T_8f803_row2_col2" class="data row2 col2" >199.500000</td>
#                         <td id="T_8f803_row2_col3" class="data row2 col3" >2.000000</td>
#                         <td id="T_8f803_row2_col4" class="data row2 col4" >10.000000</td>
#                         <td id="T_8f803_row2_col5" class="data row2 col5" >97.500000</td>
#                         <td id="T_8f803_row2_col6" class="data row2 col6" >199.500000</td>
#                         <td id="T_8f803_row2_col7" class="data row2 col7" >163.000000</td>
#                         <td id="T_8f803_row2_col8" class="data row2 col8" >147.000000</td>
#                         <td id="T_8f803_row2_col9" class="data row2 col9" >150.500000</td>
#                         <td id="T_8f803_row2_col10" class="data row2 col10" >2.000000</td>
#                         <td id="T_8f803_row2_col11" class="data row2 col11" >219.500000</td>
#             </tr>
#             <tr>
#                                 <th id="T_8f803_level1_row3" class="row_heading level1 row3" rowspan="3">110</th>
#                         <th id="T_8f803_level2_row3" class="row_heading level2 row3" >ward</th>
#                         <td id="T_8f803_row3_col0" class="data row3 col0" >179.000000</td>
#                         <td id="T_8f803_row3_col1" class="data row3 col1" >179.000000</td>
#                         <td id="T_8f803_row3_col2" class="data row3 col2" >199.000000</td>
#                         <td id="T_8f803_row3_col3" class="data row3 col3" >2.000000</td>
#                         <td id="T_8f803_row3_col4" class="data row3 col4" >10.000000</td>
#                         <td id="T_8f803_row3_col5" class="data row3 col5" >165.500000</td>
#                         <td id="T_8f803_row3_col6" class="data row3 col6" >214.500000</td>
#                         <td id="T_8f803_row3_col7" class="data row3 col7" >144.000000</td>
#                         <td id="T_8f803_row3_col8" class="data row3 col8" >211.500000</td>
#                         <td id="T_8f803_row3_col9" class="data row3 col9" >71.000000</td>
#                         <td id="T_8f803_row3_col10" class="data row3 col10" >2.000000</td>
#                         <td id="T_8f803_row3_col11" class="data row3 col11" >214.500000</td>
#             </tr>
#             <tr>
#                                         <th id="T_8f803_level2_row4" class="row_heading level2 row4" >average</th>
#                         <td id="T_8f803_row4_col0" class="data row4 col0" >159.000000</td>
#                         <td id="T_8f803_row4_col1" class="data row4 col1" >159.000000</td>
#                         <td id="T_8f803_row4_col2" class="data row4 col2" >167.500000</td>
#                         <td id="T_8f803_row4_col3" class="data row4 col3"

# %%
tree_ranks_df.loc[:, "15", :].style.background_gradient(cmap=cm, axis=0)
# Out:
# <style  type="text/css" >
# #T_76e53_row0_col0,#T_76e53_row0_col1,#T_76e53_row0_col2,#T_76e53_row0_col3,#T_76e53_row0_col4,#T_76e53_row0_col5,#T_76e53_row0_col6,#T_76e53_row0_col7,#T_76e53_row0_col10,#T_76e53_row0_col11,#T_76e53_row1_col3,#T_76e53_row1_col8,#T_76e53_row1_col9,#T_76e53_row1_col10,#T_76e53_row2_col3,#T_76e53_row2_col10{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_76e53_row0_col8,#T_76e53_row0_col9,#T_76e53_row1_col4,#T_76e53_row1_col7,#T_76e53_row1_col11,#T_76e53_row2_col0,#T_76e53_row2_col1,#T_76e53_row2_col2,#T_76e53_row2_col5,#T_76e53_row2_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_76e53_row1_col0,#T_76e53_row1_col1,#T_76e53_row2_col8{
#             background-color:  #4747fb;
#             color:  #f1f1f1;
#         }#T_76e53_row1_col2,#T_76e53_row1_col6{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_76e53_row1_col5{
#             background-color:  #1111fe;
#             color:  #f1f1f1;
#         }#T_76e53_row2_col4{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_76e53_row2_col7{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_76e53_row2_col9{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_76e53_row2_col11{
#             background-color:  #efeff3;
#             color:  #000000;
#         }</style><table id="T_76e53_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EGFR-SLK</th>        <th class="col_heading level0 col1" >EGFR-LOK</th>        <th class="col_heading level0 col2" >EGFR-GAK</th>        <th class="col_heading level0 col3" >SLK-LOK</th>        <th class="col_heading level0 col4" >DRAK2-CaMKK2</th>        <th class="col_heading level0 col5" >ABL2-AurA</th>        <th class="col_heading level0 col6" >ABL1-GAK</th>        <th class="col_heading level0 col7" >GAK-DAPK3</th>        <th class="col_heading level0 col8" >AurC-KIT</th>        <th class="col_heading level0 col9" >KIT-AMPKa2</th>        <th class="col_heading level0 col10" >KIT-FMS</th>        <th class="col_heading level0 col11" >ABL1-BMPR1B</th>    </tr>    <tr>        <th class="index_name level0" >subset</th>        <th class="index_name level1" >cmethod</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T