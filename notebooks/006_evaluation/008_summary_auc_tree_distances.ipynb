# %% [markdown]
# # Performance summary over different `kissim` setups
#
# Summarize performance of different `kissim` setups:
#
# - Profiling vs. `kissim` AUCs: How well does `kissim` reflect profiling data?
# - Phylogenetic `kissim` tree: How well do selected on- and off-targets cluster together?
# - Top `kissim` ranks: How high do selected on- and off-targets rank in `kissim`?
#
# DFG-in conformations only!

# %%
from pathlib import Path

import pandas as pd
import seaborn as sns
from Bio import Phylo

from src.paths import PATH_RESULTS

# %%
cm = sns.light_palette("blue", as_cmap=True)

# %%
HERE = Path(_dh[-1])  # noqa: F821
RESULTS = PATH_RESULTS

# %% [markdown]
# ## `kissim` setups

# %%
DATA_SUBSET = [
    "dfg_in",
]
WEIGHTING_SCHEMES = ["15", "110", "101", "100"]
CLUSTERING_METHODS = ["ward", "average", "weighted"]

# %%
ON_OFF_PAIRS = [
    ["EGFR", ["SLK", "LOK", "GAK"]],  # Erlotinib
    ["SLK", ["LOK"]],  # Erlotinib
    ["DRAK2", ["CaMKK2"]],
    ["ABL2", ["AurA"]],  # VX-680/MK-0457
    ["ABL1", ["GAK"]],  # Dasatinib
    ["GAK", ["DAPK3"]],  # Inrebic
    ["AurC", ["KIT"]],  # Inlyta
    ["KIT", ["AMPKa2", "FMS"]],  # JNJ-28312141
    ["ABL1", ["BMPR1B"]],  # PD-173955
]

# %% [markdown]
# ## Profiling vs. `kissim` AUCs

# %%
auc_dfs = {}
mean_df = []
median_df = []
std_df = []
for data_subset in DATA_SUBSET:
    path = RESULTS / data_subset
    auc_df = pd.read_csv(path / "auc/auc_kissim_vs_karaman-davis__feature_weights.csv")
    auc_dfs[data_subset] = auc_df[["15", "100", "110", "101", "111"]]

    mean = auc_dfs[data_subset].describe().loc["mean", :]
    mean.name = data_subset
    mean_df.append(mean)

    median = auc_dfs[data_subset].describe().loc["50%", :]
    median.name = data_subset
    median_df.append(median)

    std = auc_dfs[data_subset].describe().loc["std", :]
    std.name = data_subset
    std_df.append(std)
mean_df = pd.concat(mean_df, axis=1)
median_df = pd.concat(median_df, axis=1)
std_df = pd.concat(std_df, axis=1)

# %% [markdown]
# ### Mean

# %%
mean_df.style.background_gradient(cmap=cm, axis=None)
# Out:
# <style type="text/css">
# #T_06b0b_row0_col0 {
#   background-color: #7c7cf9;
#   color: #f1f1f1;
# }
# #T_06b0b_row1_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_06b0b_row2_col0 {
#   background-color: #4040fc;
#   color: #f1f1f1;
# }
# #T_06b0b_row3_col0 {
#   background-color: #b6b6f6;
#   color: #000000;
# }
# #T_06b0b_row4_col0 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_06b0b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >dfg_in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06b0b_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_06b0b_row0_col0" class="data row0 col0" >0.756266</td>
#     </tr>
#     <tr>
#       <th id="T_06b0b_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_06b0b_row1_col0" class="data row1 col0" >0.763467</td>
#     </tr>
#     <tr>
#       <th id="T_06b0b_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_06b0b_row2_col0" class="data row2 col0" >0.759750</td>
#     </tr>
#     <tr>
#       <th id="T_06b0b_level0_row3" class="row_heading level0 row3" >101</th>
#       <td id="T_06b0b_row3_col0" class="data row3 col0" >0.752886</td>
#     </tr>
#     <tr>
#       <th id="T_06b0b_level0_row4" class="row_heading level0 row4" >111</th>
#       <td id="T_06b0b_row4_col0" class="data row4 col0" >0.749477</td>
#     </tr>
#   </tbody>
# </table>

# %%
mean_df.style.highlight_max(axis=0, color="yellow")
# Out:
# <style type="text/css">
# #T_f6404_row1_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f6404_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >dfg_in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6404_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_f6404_row0_col0" class="data row0 col0" >0.756266</td>
#     </tr>
#     <tr>
#       <th id="T_f6404_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_f6404_row1_col0" class="data row1 col0" >0.763467</td>
#     </tr>
#     <tr>
#       <th id="T_f6404_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_f6404_row2_col0" class="data row2 col0" >0.759750</td>
#     </tr>
#     <tr>
#       <th id="T_f6404_level0_row3" class="row_heading level0 row3" >101</th>
#       <td id="T_f6404_row3_col0" class="data row3 col0" >0.752886</td>
#     </tr>
#     <tr>
#       <th id="T_f6404_level0_row4" class="row_heading level0 row4" >111</th>
#       <td id="T_f6404_row4_col0" class="data row4 col0" >0.749477</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Median

# %%
median_df.style.background_gradient(cmap=cm, axis=None)
# Out:
# <style type="text/css">
# #T_244f4_row0_col0 {
#   background-color: #a8a8f6;
#   color: #000000;
# }
# #T_244f4_row1_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_244f4_row2_col0 {
#   background-color: #3939fc;
#   color: #f1f1f1;
# }
# #T_244f4_row3_col0 {
#   background-color: #cdcdf5;
#   color: #000000;
# }
# #T_244f4_row4_col0 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_244f4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >dfg_in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_244f4_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_244f4_row0_col0" class="data row0 col0" >0.782306</td>
#     </tr>
#     <tr>
#       <th id="T_244f4_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_244f4_row1_col0" class="data row1 col0" >0.799908</td>
#     </tr>
#     <tr>
#       <th id="T_244f4_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_244f4_row2_col0" class="data row2 col0" >0.793960</td>
#     </tr>
#     <tr>
#       <th id="T_244f4_level0_row3" class="row_heading level0 row3" >101</th>
#       <td id="T_244f4_row3_col0" class="data row3 col0" >0.778464</td>
#     </tr>
#     <tr>
#       <th id="T_244f4_level0_row4" class="row_heading level0 row4" >111</th>
#       <td id="T_244f4_row4_col0" class="data row4 col0" >0.774696</td>
#     </tr>
#   </tbody>
# </table>

# %%
median_df.style.highlight_max(axis=0, color="yellow")
# Out:
# <style type="text/css">
# #T_afcd9_row1_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_afcd9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >dfg_in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afcd9_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_afcd9_row0_col0" class="data row0 col0" >0.782306</td>
#     </tr>
#     <tr>
#       <th id="T_afcd9_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_afcd9_row1_col0" class="data row1 col0" >0.799908</td>
#     </tr>
#     <tr>
#       <th id="T_afcd9_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_afcd9_row2_col0" class="data row2 col0" >0.793960</td>
#     </tr>
#     <tr>
#       <th id="T_afcd9_level0_row3" class="row_heading level0 row3" >101</th>
#       <td id="T_afcd9_row3_col0" class="data row3 col0" >0.778464</td>
#     </tr>
#     <tr>
#       <th id="T_afcd9_level0_row4" class="row_heading level0 row4" >111</th>
#       <td id="T_afcd9_row4_col0" class="data row4 col0" >0.774696</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Standard deviation

# %%
std_df.style.background_gradient(cmap=cm, axis=None)
# Out:
# <style type="text/css">
# #T_a8f13_row0_col0 {
#   background-color: #9595f7;
#   color: #f1f1f1;
# }
# #T_a8f13_row1_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_a8f13_row2_col0 {
#   background-color: #4848fb;
#   color: #f1f1f1;
# }
# #T_a8f13_row3_col0 {
#   background-color: #babaf6;
#   color: #000000;
# }
# #T_a8f13_row4_col0 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_a8f13_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >dfg_in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f13_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_a8f13_row0_col0" class="data row0 col0" >0.121349</td>
#     </tr>
#     <tr>
#       <th id="T_a8f13_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_a8f13_row1_col0" class="data row1 col0" >0.124534</td>
#     </tr>
#     <tr>
#       <th id="T_a8f13_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_a8f13_row2_col0" class="data row2 col0" >0.123001</td>
#     </tr>
#     <tr>
#       <th id="T_a8f13_level0_row3" class="row_heading level0 row3" >101</th>
#       <td id="T_a8f13_row3_col0" class="data row3 col0" >0.120553</td>
#     </tr>
#     <tr>
#       <th id="T_a8f13_level0_row4" class="row_heading level0 row4" >111</th>
#       <td id="T_a8f13_row4_col0" class="data row4 col0" >0.119376</td>
#     </tr>
#   </tbody>
# </table>

# %%
std_df.style.highlight_max(axis=0, color="yellow")
# Out:
# <style type="text/css">
# #T_2e744_row1_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2e744_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >dfg_in</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e744_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_2e744_row0_col0" class="data row0 col0" >0.121349</td>
#     </tr>
#     <tr>
#       <th id="T_2e744_level0_row1" class="row_heading level0 row1" >100</th>
#       <td id="T_2e744_row1_col0" class="data row1 col0" >0.124534</td>
#     </tr>
#     <tr>
#       <th id="T_2e744_level0_row2" class="row_heading level0 row2" >110</th>
#       <td id="T_2e744_row2_col0" class="data row2 col0" >0.123001</td>
#     </tr>
#     <tr>
#       <th id="T_2e744_level0_row3" class="row_heading level0 row3" >101</th>
#       <td id="T_2e744_row3_col0" class="data row3 col0" >0.120553</td>
#     </tr>
#     <tr>
#       <th id="T_2e744_level0_row4" class="row_heading level0 row4" >111</th>
#       <td id="T_2e744_row4_col0" class="data row4 col0" >0.119376</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Top `kissim` ranks

# %%
def get_ranks(distance_matrix, rank_from, rank_to):
    """
    Get ranks for all kinases w.r.t. to a query kinase.
    """

    ranks = pd.concat(
        [
            distance_matrix[rank_from].sort_values(),
            distance_matrix[rank_from].sort_values().rank(),
        ],
        axis=1,
    )
    ranks.columns = ["distance", "rank"]
    if rank_to is not None:
        ranks = ranks.loc[rank_to, :]
    pair_names = [f"{rank_from}-{rank_to}" for i in rank_to]
    return ranks, pair_names

# %%
# %%time

results_list = []

for data_subset in DATA_SUBSET:
    for weighting in WEIGHTING_SCHEMES:
        results = []
        columns = []
        results.extend([data_subset, weighting])

        kinase_matrix_path = RESULTS / f"{data_subset}/fingerprint_distances_to_kinase_matrix.csv"
        kinase_matrix = pd.read_csv(kinase_matrix_path, index_col=0)

        for pair in ON_OFF_PAIRS:
            try:
                ranks, pair_names = get_ranks(kinase_matrix, pair[0], pair[1])
                results.extend(ranks["rank"].to_list())
            except KeyError:
                results.extend([None] * len(pair[1]))

        results_list.append(results)
# Out:
# CPU times: user 547 ms, sys: 31.7 ms, total: 579 ms
# Wall time: 589 ms

# %%
len(["subset", "weighting"] + [f"{i[0]}-{j}" for i in ON_OFF_PAIRS for j in i[1]])
# Out:
# 14

# %%
matrix_ranks_df = pd.DataFrame(
    results_list,
    columns=["subset", "weighting"] + [f"{i[0]}-{j}" for i in ON_OFF_PAIRS for j in i[1]],
)
matrix_ranks_df = matrix_ranks_df.set_index(["subset", "weighting"])
cm = sns.light_palette("blue", as_cmap=True, reverse=True)

# %%
matrix_ranks_df
# Out:
#                   EGFR-SLK  EGFR-LOK  EGFR-GAK  SLK-LOK  DRAK2-CaMKK2  \
# subset weighting
# dfg_in 15             44.0      27.0     183.0      2.0           5.0
#        110            44.0      27.0     183.0      2.0           5.0
#        101            44.0      27.0     183.0      2.0           5.0
#        100            44.0      27.0     183.0      2.0           5.0
#
#                   ABL2-AurA  ABL1-GAK  GAK-DAPK3  AurC-KIT  KIT-AMPKa2  \
# subset weighting
# dfg_in 15              87.0     126.0       11.0     127.0        74.0
#        110             87.0     126.0       11.0     127.0        74.0
#        101             87.0     126.0       11.0     127.0        74.0
#        100             87.0     126.0       11.0     127.0        74.0
#
#                   KIT-FMS  ABL1-BMPR1B
# subset weighting
# dfg_in 15             2.0        220.0
#        110            2.0        220.0
#        101            2.0        220.0
#        100            2.0        220.0

# %%
matrix_ranks_df.dropna(axis=1).style.applymap(
    lambda x: "background-color : yellow" if x < 25 else ""
)
# Out:
# <style type="text/css">
# #T_23d74_row0_col3, #T_23d74_row0_col4, #T_23d74_row0_col7, #T_23d74_row0_col10, #T_23d74_row1_col3, #T_23d74_row1_col4, #T_23d74_row1_col7, #T_23d74_row1_col10, #T_23d74_row2_col3, #T_23d74_row2_col4, #T_23d74_row2_col7, #T_23d74_row2_col10, #T_23d74_row3_col3, #T_23d74_row3_col4, #T_23d74_row3_col7, #T_23d74_row3_col10 {
#   background-color: yellow;
# }
# </style>
# <table id="T_23d74_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >EGFR-SLK</th>
#       <th class="col_heading level0 col1" >EGFR-LOK</th>
#       <th class="col_heading level0 col2" >EGFR-GAK</th>
#       <th class="col_heading level0 col3" >SLK-LOK</th>
#       <th class="col_heading level0 col4" >DRAK2-CaMKK2</th>
#       <th class="col_heading level0 col5" >ABL2-AurA</th>
#       <th class="col_heading level0 col6" >ABL1-GAK</th>
#       <th class="col_heading level0 col7" >GAK-DAPK3</th>
#       <th class="col_heading level0 col8" >AurC-KIT</th>
#       <th class="col_heading level0 col9" >KIT-AMPKa2</th>
#       <th class="col_heading level0 col10" >KIT-FMS</th>
#       <th class="col_heading level0 col11" >ABL1-BMPR1B</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subset</th>
#       <th class="index_name level1" >weighting</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23d74_level0_row0" class="row_heading level0 row0" rowspan="4">dfg_in</th>
#       <th id="T_23d74_level1_row0" class="row_heading level1 row0" >15</th>
#       <td id="T_23d74_row0_col0" class="data row0 col0" >44.000000</td>
#       <td id="T_23d74_row0_col1" class="data row0 col1" >27.000000</td>
#       <td id="T_23d74_row0_col2" class="data row0 col2" >183.000000</td>
#       <td id="T_23d74_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_23d74_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_23d74_row0_col5" class="data row0 col5" >87.000000</td>
#       <td id="T_23d74_row0_col6" class="data row0 col6" >126.000000</td>
#       <td id="T_23d74_row0_col7" class="data row0 col7" >11.000000</td>
#       <td id="T_23d74_row0_col8" class="data row0 col8" >127.000000</td>
#       <td id="T_23d74_row0_col9" class="data row0 col9" >74.000000</td>
#       <td id="T_23d74_row0_col10" class="data row0 col10" >2.000000</td>
#       <td id="T_23d74_row0_col11" class="data row0 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d74_level1_row1" class="row_heading level1 row1" >110</th>
#       <td id="T_23d74_row1_col0" class="data row1 col0" >44.000000</td>
#       <td id="T_23d74_row1_col1" class="data row1 col1" >27.000000</td>
#       <td id="T_23d74_row1_col2" class="data row1 col2" >183.000000</td>
#       <td id="T_23d74_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_23d74_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_23d74_row1_col5" class="data row1 col5" >87.000000</td>
#       <td id="T_23d74_row1_col6" class="data row1 col6" >126.000000</td>
#       <td id="T_23d74_row1_col7" class="data row1 col7" >11.000000</td>
#       <td id="T_23d74_row1_col8" class="data row1 col8" >127.000000</td>
#       <td id="T_23d74_row1_col9" class="data row1 col9" >74.000000</td>
#       <td id="T_23d74_row1_col10" class="data row1 col10" >2.000000</td>
#       <td id="T_23d74_row1_col11" class="data row1 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d74_level1_row2" class="row_heading level1 row2" >101</th>
#       <td id="T_23d74_row2_col0" class="data row2 col0" >44.000000</td>
#       <td id="T_23d74_row2_col1" class="data row2 col1" >27.000000</td>
#       <td id="T_23d74_row2_col2" class="data row2 col2" >183.000000</td>
#       <td id="T_23d74_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_23d74_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_23d74_row2_col5" class="data row2 col5" >87.000000</td>
#       <td id="T_23d74_row2_col6" class="data row2 col6" >126.000000</td>
#       <td id="T_23d74_row2_col7" class="data row2 col7" >11.000000</td>
#       <td id="T_23d74_row2_col8" class="data row2 col8" >127.000000</td>
#       <td id="T_23d74_row2_col9" class="data row2 col9" >74.000000</td>
#       <td id="T_23d74_row2_col10" class="data row2 col10" >2.000000</td>
#       <td id="T_23d74_row2_col11" class="data row2 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d74_level1_row3" class="row_heading level1 row3" >100</th>
#       <td id="T_23d74_row3_col0" class="data row3 col0" >44.000000</td>
#       <td id="T_23d74_row3_col1" class="data row3 col1" >27.000000</td>
#       <td id="T_23d74_row3_col2" class="data row3 col2" >183.000000</td>
#       <td id="T_23d74_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_23d74_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_23d74_row3_col5" class="data row3 col5" >87.000000</td>
#       <td id="T_23d74_row3_col6" class="data row3 col6" >126.000000</td>
#       <td id="T_23d74_row3_col7" class="data row3 col7" >11.000000</td>
#       <td id="T_23d74_row3_col8" class="data row3 col8" >127.000000</td>
#       <td id="T_23d74_row3_col9" class="data row3 col9" >74.000000</td>
#       <td id="T_23d74_row3_col10" class="data row3 col10" >2.000000</td>
#       <td id="T_23d74_row3_col11" class="data row3 col11" >220.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
matrix_ranks_df.dropna(axis=1).style.background_gradient(cmap=cm, axis=None)
# Out:
# <style type="text/css">
# #T_f6aea_row0_col0, #T_f6aea_row1_col0, #T_f6aea_row2_col0, #T_f6aea_row3_col0 {
#   background-color: #2e2efd;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col1, #T_f6aea_row1_col1, #T_f6aea_row2_col1, #T_f6aea_row3_col1 {
#   background-color: #1b1bfe;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col2, #T_f6aea_row1_col2, #T_f6aea_row2_col2, #T_f6aea_row3_col2 {
#   background-color: #c8c8f5;
#   color: #000000;
# }
# #T_f6aea_row0_col3, #T_f6aea_row0_col10, #T_f6aea_row1_col3, #T_f6aea_row1_col10, #T_f6aea_row2_col3, #T_f6aea_row2_col10, #T_f6aea_row3_col3, #T_f6aea_row3_col10 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col4, #T_f6aea_row1_col4, #T_f6aea_row2_col4, #T_f6aea_row3_col4 {
#   background-color: #0303ff;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col5, #T_f6aea_row1_col5, #T_f6aea_row2_col5, #T_f6aea_row3_col5 {
#   background-color: #5d5dfa;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col6, #T_f6aea_row1_col6, #T_f6aea_row2_col6, #T_f6aea_row3_col6 {
#   background-color: #8989f8;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col7, #T_f6aea_row1_col7, #T_f6aea_row2_col7, #T_f6aea_row3_col7 {
#   background-color: #0909ff;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col8, #T_f6aea_row1_col8, #T_f6aea_row2_col8, #T_f6aea_row3_col8 {
#   background-color: #8a8af8;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col9, #T_f6aea_row1_col9, #T_f6aea_row2_col9, #T_f6aea_row3_col9 {
#   background-color: #4f4ffb;
#   color: #f1f1f1;
# }
# #T_f6aea_row0_col11, #T_f6aea_row1_col11, #T_f6aea_row2_col11, #T_f6aea_row3_col11 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_f6aea_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >EGFR-SLK</th>
#       <th class="col_heading level0 col1" >EGFR-LOK</th>
#       <th class="col_heading level0 col2" >EGFR-GAK</th>
#       <th class="col_heading level0 col3" >SLK-LOK</th>
#       <th class="col_heading level0 col4" >DRAK2-CaMKK2</th>
#       <th class="col_heading level0 col5" >ABL2-AurA</th>
#       <th class="col_heading level0 col6" >ABL1-GAK</th>
#       <th class="col_heading level0 col7" >GAK-DAPK3</th>
#       <th class="col_heading level0 col8" >AurC-KIT</th>
#       <th class="col_heading level0 col9" >KIT-AMPKa2</th>
#       <th class="col_heading level0 col10" >KIT-FMS</th>
#       <th class="col_heading level0 col11" >ABL1-BMPR1B</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subset</th>
#       <th class="index_name level1" >weighting</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6aea_level0_row0" class="row_heading level0 row0" rowspan="4">dfg_in</th>
#       <th id="T_f6aea_level1_row0" class="row_heading level1 row0" >15</th>
#       <td id="T_f6aea_row0_col0" class="data row0 col0" >44.000000</td>
#       <td id="T_f6aea_row0_col1" class="data row0 col1" >27.000000</td>
#       <td id="T_f6aea_row0_col2" class="data row0 col2" >183.000000</td>
#       <td id="T_f6aea_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_f6aea_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_f6aea_row0_col5" class="data row0 col5" >87.000000</td>
#       <td id="T_f6aea_row0_col6" class="data row0 col6" >126.000000</td>
#       <td id="T_f6aea_row0_col7" class="data row0 col7" >11.000000</td>
#       <td id="T_f6aea_row0_col8" class="data row0 col8" >127.000000</td>
#       <td id="T_f6aea_row0_col9" class="data row0 col9" >74.000000</td>
#       <td id="T_f6aea_row0_col10" class="data row0 col10" >2.000000</td>
#       <td id="T_f6aea_row0_col11" class="data row0 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6aea_level1_row1" class="row_heading level1 row1" >110</th>
#       <td id="T_f6aea_row1_col0" class="data row1 col0" >44.000000</td>
#       <td id="T_f6aea_row1_col1" class="data row1 col1" >27.000000</td>
#       <td id="T_f6aea_row1_col2" class="data row1 col2" >183.000000</td>
#       <td id="T_f6aea_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_f6aea_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_f6aea_row1_col5" class="data row1 col5" >87.000000</td>
#       <td id="T_f6aea_row1_col6" class="data row1 col6" >126.000000</td>
#       <td id="T_f6aea_row1_col7" class="data row1 col7" >11.000000</td>
#       <td id="T_f6aea_row1_col8" class="data row1 col8" >127.000000</td>
#       <td id="T_f6aea_row1_col9" class="data row1 col9" >74.000000</td>
#       <td id="T_f6aea_row1_col10" class="data row1 col10" >2.000000</td>
#       <td id="T_f6aea_row1_col11" class="data row1 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6aea_level1_row2" class="row_heading level1 row2" >101</th>
#       <td id="T_f6aea_row2_col0" class="data row2 col0" >44.000000</td>
#       <td id="T_f6aea_row2_col1" class="data row2 col1" >27.000000</td>
#       <td id="T_f6aea_row2_col2" class="data row2 col2" >183.000000</td>
#       <td id="T_f6aea_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_f6aea_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_f6aea_row2_col5" class="data row2 col5" >87.000000</td>
#       <td id="T_f6aea_row2_col6" class="data row2 col6" >126.000000</td>
#       <td id="T_f6aea_row2_col7" class="data row2 col7" >11.000000</td>
#       <td id="T_f6aea_row2_col8" class="data row2 col8" >127.000000</td>
#       <td id="T_f6aea_row2_col9" class="data row2 col9" >74.000000</td>
#       <td id="T_f6aea_row2_col10" class="data row2 col10" >2.000000</td>
#       <td id="T_f6aea_row2_col11" class="data row2 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6aea_level1_row3" class="row_heading level1 row3" >100</th>
#       <td id="T_f6aea_row3_col0" class="data row3 col0" >44.000000</td>
#       <td id="T_f6aea_row3_col1" class="data row3 col1" >27.000000</td>
#       <td id="T_f6aea_row3_col2" class="data row3 col2" >183.000000</td>
#       <td id="T_f6aea_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_f6aea_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_f6aea_row3_col5" class="data row3 col5" >87.000000</td>
#       <td id="T_f6aea_row3_col6" class="data row3 col6" >126.000000</td>
#       <td id="T_f6aea_row3_col7" class="data row3 col7" >11.000000</td>
#       <td id="T_f6aea_row3_col8" class="data row3 col8" >127.000000</td>
#       <td id="T_f6aea_row3_col9" class="data row3 col9" >74.000000</td>
#       <td id="T_f6aea_row3_col10" class="data row3 col10" >2.000000</td>
#       <td id="T_f6aea_row3_col11" class="data row3 col11" >220.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Ranks

# %%
from kissim.comparison import FingerprintDistanceGenerator
from src.definitions import COVERAGE_CUTOFF

# %%
fingerprint_distances = FingerprintDistanceGenerator.from_csv(
    RESULTS / f"{DATA_SUBSET[0]}/fingerprint_distances.csv.bz2"
)

# %%
kinase_matrix = fingerprint_distances.kinase_distance_matrix(coverage_min=COVERAGE_CUTOFF)

# %%
kinase_matrix[["EGFR"]]
# Out:
# kinase.2      EGFR
# kinase.1
# AAK1      0.111434
# ABL1      0.063537
# ABL2      0.067081
# ACK       0.066619
# ACTR2     0.121684
# ...            ...
# p38a      0.091348
# p38b      0.095911
# p38d      0.101236
# p38g      0.094483
# p70S6K    0.093458
#
# [257 rows x 1 columns]

# %%
from opencadd.databases.klifs import setup_remote

# %%
klifs_session = setup_remote()

kinase_names = kinase_matrix["EGFR"].index.to_list()
kinase_groups = klifs_session.kinases.by_kinase_name(kinase_names, species="Human")[
    ["kinase.klifs_name", "kinase.group"]
]
kinase_groups = kinase_groups.set_index("kinase.klifs_name").squeeze()

kinase_ranks = kinase_matrix["EGFR"]
kinase_ranks.name = "ranks"
kinase_ranks.index.name = "kinase.klifs_name"

kinase_ranks = pd.merge(
    kinase_groups, kinase_ranks, left_index=True, right_index=True
).reset_index()

# %%
kinase_ranks.sort_values("ranks").head(50)
# Out:
#     kinase.klifs_name kinase.group     ranks
# 86               EGFR           TK  0.000000
# 76              ErbB4           TK  0.024878
# 88              ErbB2           TK  0.039648
# 89              ErbB3           TK  0.046541
# 126               SYK           TK  0.053504
# 92              FGFR4           TK  0.061678
# 183               BTK           TK  0.062406
# 166              ABL1           TK  0.063537
# 115               RET           TK  0.064704
# 190             IGF1R           TK  0.065141
# 120               ITK           TK  0.065798
# 93               INSR           TK  0.065843
# 217               ALK           TK  0.066320
# 117               ACK           TK  0.066619
# 156             ZAP70           TK  0.066839
# 174             EphB1           TK  0.067006
# 167              ABL2           TK  0.067081
# 90              FGFR2           TK  0.067322
# 109               KDR           TK  0.068191
# 91              FGFR3           TK  0.069535
# 236               ROS           TK  0.069887
# 204               RON           TK  0.069893
# 127              TIE2           TK  0.069939
# 77              FGFR1           TK  0.070023
# 73              EphA3           TK  0.070260
# 187             EphA2           TK  0.070303
# 220               LOK          STE  0.071240
# 135               FAK           TK  0.071315
# 143               FES           TK  0.071861
# 145               HCK           TK  0.072395
# 98                MER           TK  0.073024
# 94               JAK3           TK  0.073378
# 105               FMS           TK  0.073398
# 136               BRK           TK  0.073439
# 191               KIT           TK  0.073804
# 147               LYN           TK  0.073851
# 146              JAK2           TK  0.074075
# 189             EphB4           TK  0.074081
# 75              EphB2           TK  0.075161
# 87              EphA7           TK  0.075370
# 211               LCK           TK  0.075684
# 194               MET           TK  0.076089
# 108              JAK1           TK  0.076308
# 140               SLK          STE  0.076408
# 177               SRC           TK  0.076984
# 114              PYK2           TK  0.077229
# 74              EphA5           TK  0.077300
# 144             GSK3B         CMGC  0.077366
# 103               AXL           TK  0.077769
# 152              MST1          STE  0.078574

# %% [markdown]
# ## Phylogenetic `kissim` tree

# %%
import itertools
import numpy as np

# %%
def pairs_to_symmetric_matrix(pairs):
    """
    Create symmetric matrix with diagonal of 0.0 from pair combinations.
    """

    pairs1 = pd.DataFrame(pairs)
    pairs2 = pairs1[[1, 0, 2]]
    pairs2.columns = [0, 1, 2]
    pairs_all = pd.concat([pairs1, pairs2])
    matrix = pairs_all.pivot(index=0, columns=1, values=2)
    np.fill_diagonal(matrix.values, 0.0)
    symmetic_matrix = pd.DataFrame(matrix.values, columns=matrix.columns, index=matrix.index)
    return symmetic_matrix

# %%
def get_tree_distance_matrix(tree):
    """
    Get a matrix of all-against-all kinase distances in the kinase tree.
    """

    kinases = [clade.name for clade in tree.get_terminals()]
    kinase_pairs = itertools.combinations(kinases, 2)

    kinase_pairs_tree_distances = []

    for kinase1, kinase2 in kinase_pairs:
        kinase_pairs_tree_distances.append([kinase1, kinase2, tree.distance(kinase1, kinase2)])

    tree_distance_matrix = pairs_to_symmetric_matrix(kinase_pairs_tree_distances)

    return tree_distance_matrix

# %%
# %%time

results_list = []

for data_subset in DATA_SUBSET:
    for weighting in WEIGHTING_SCHEMES:
        for cmethod in CLUSTERING_METHODS:
            results = []
            results.extend([data_subset, weighting, cmethod])

            tree_path = RESULTS / f"{data_subset}/trees/tree_0.8_{weighting}_{cmethod}.tree"
            kissim_tree = Phylo.read(tree_path, "newick")
            tree_distance_matrix = get_tree_distance_matrix(kissim_tree)

            for pair in ON_OFF_PAIRS:
                try:
                    ranks, pair_names = get_ranks(kinase_matrix, pair[0], pair[1])
                    results.extend(ranks["rank"].to_list())
                except KeyError:
                    results.extend([None] * len(pair[1]))

            results_list.append(results)
# Out:
# CPU times: user 9min 40s, sys: 143 ms, total: 9min 40s
# Wall time: 9min 40s

# %%
tree_ranks_df = pd.DataFrame(
    results_list,
    columns=["subset", "weighting", "cmethod"]
    + [f"{i[0]}-{j}" for i in ON_OFF_PAIRS for j in i[1]],
)
tree_ranks_df = tree_ranks_df.set_index(["subset", "weighting", "cmethod"])
cm = sns.light_palette("blue", as_cmap=True, reverse=True)

# %%
tree_ranks_df.dropna(axis=1).style.applymap(
    lambda x: "background-color : yellow" if x < 25 else ""
)
# Out:
# <style type="text/css">
# #T_46951_row0_col3, #T_46951_row0_col4, #T_46951_row0_col7, #T_46951_row0_col10, #T_46951_row1_col3, #T_46951_row1_col4, #T_46951_row1_col7, #T_46951_row1_col10, #T_46951_row2_col3, #T_46951_row2_col4, #T_46951_row2_col7, #T_46951_row2_col10, #T_46951_row3_col3, #T_46951_row3_col4, #T_46951_row3_col7, #T_46951_row3_col10, #T_46951_row4_col3, #T_46951_row4_col4, #T_46951_row4_col7, #T_46951_row4_col10, #T_46951_row5_col3, #T_46951_row5_col4, #T_46951_row5_col7, #T_46951_row5_col10, #T_46951_row6_col3, #T_46951_row6_col4, #T_46951_row6_col7, #T_46951_row6_col10, #T_46951_row7_col3, #T_46951_row7_col4, #T_46951_row7_col7, #T_46951_row7_col10, #T_46951_row8_col3, #T_46951_row8_col4, #T_46951_row8_col7, #T_46951_row8_col10, #T_46951_row9_col3, #T_46951_row9_col4, #T_46951_row9_col7, #T_46951_row9_col10, #T_46951_row10_col3, #T_46951_row10_col4, #T_46951_row10_col7, #T_46951_row10_col10, #T_46951_row11_col3, #T_46951_row11_col4, #T_46951_row11_col7, #T_46951_row11_col10 {
#   background-color: yellow;
# }
# </style>
# <table id="T_46951_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >EGFR-SLK</th>
#       <th class="col_heading level0 col1" >EGFR-LOK</th>
#       <th class="col_heading level0 col2" >EGFR-GAK</th>
#       <th class="col_heading level0 col3" >SLK-LOK</th>
#       <th class="col_heading level0 col4" >DRAK2-CaMKK2</th>
#       <th class="col_heading level0 col5" >ABL2-AurA</th>
#       <th class="col_heading level0 col6" >ABL1-GAK</th>
#       <th class="col_heading level0 col7" >GAK-DAPK3</th>
#       <th class="col_heading level0 col8" >AurC-KIT</th>
#       <th class="col_heading level0 col9" >KIT-AMPKa2</th>
#       <th class="col_heading level0 col10" >KIT-FMS</th>
#       <th class="col_heading level0 col11" >ABL1-BMPR1B</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subset</th>
#       <th class="index_name level1" >weighting</th>
#       <th class="index_name level2" >cmethod</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46951_level0_row0" class="row_heading level0 row0" rowspan="12">dfg_in</th>
#       <th id="T_46951_level1_row0" class="row_heading level1 row0" rowspan="3">15</th>
#       <th id="T_46951_level2_row0" class="row_heading level2 row0" >ward</th>
#       <td id="T_46951_row0_col0" class="data row0 col0" >44.000000</td>
#       <td id="T_46951_row0_col1" class="data row0 col1" >27.000000</td>
#       <td id="T_46951_row0_col2" class="data row0 col2" >183.000000</td>
#       <td id="T_46951_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_46951_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_46951_row0_col5" class="data row0 col5" >87.000000</td>
#       <td id="T_46951_row0_col6" class="data row0 col6" >126.000000</td>
#       <td id="T_46951_row0_col7" class="data row0 col7" >11.000000</td>
#       <td id="T_46951_row0_col8" class="data row0 col8" >127.000000</td>
#       <td id="T_46951_row0_col9" class="data row0 col9" >74.000000</td>
#       <td id="T_46951_row0_col10" class="data row0 col10" >2.000000</td>
#       <td id="T_46951_row0_col11" class="data row0 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46951_level2_row1" class="row_heading level2 row1" >average</th>
#       <td id="T_46951_row1_col0" class="data row1 col0" >44.000000</td>
#       <td id="T_46951_row1_col1" class="data row1 col1" >27.000000</td>
#       <td id="T_46951_row1_col2" class="data row1 col2" >183.000000</td>
#       <td id="T_46951_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_46951_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_46951_row1_col5" class="data row1 col5" >87.000000</td>
#       <td id="T_46951_row1_col6" class="data row1 col6" >126.000000</td>
#       <td id="T_46951_row1_col7" class="data row1 col7" >11.000000</td>
#       <td id="T_46951_row1_col8" class="data row1 col8" >127.000000</td>
#       <td id="T_46951_row1_col9" class="data row1 col9" >74.000000</td>
#       <td id="T_46951_row1_col10" class="data row1 col10" >2.000000</td>
#       <td id="T_46951_row1_col11" class="data row1 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46951_level2_row2" class="row_heading level2 row2" >weighted</th>
#       <td id="T_46951_row2_col0" class="data row2 col0" >44.000000</td>
#       <td id="T_46951_row2_col1" class="data row2 col1" >27.000000</td>
#       <td id="T_46951_row2_col2" class="data row2 col2" >183.000000</td>
#       <td id="T_46951_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_46951_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_46951_row2_col5" class="data row2 col5" >87.000000</td>
#       <td id="T_46951_row2_col6" class="data row2 col6" >126.000000</td>
#       <td id="T_46951_row2_col7" class="data row2 col7" >11.000000</td>
#       <td id="T_46951_row2_col8" class="data row2 col8" >127.000000</td>
#       <td id="T_46951_row2_col9" class="data row2 col9" >74.000000</td>
#       <td id="T_46951_row2_col10" class="data row2 col10" >2.000000</td>
#       <td id="T_46951_row2_col11" class="data row2 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46951_level1_row3" class="row_heading level1 row3" rowspan="3">110</th>
#       <th id="T_46951_level2_row3" class="row_heading level2 row3" >ward</th>
#       <td id="T_46951_row3_col0" class="data row3 col0" >44.000000</td>
#       <td id="T_46951_row3_col1" class="data row3 col1" >27.000000</td>
#       <td id="T_46951_row3_col2" class="data row3 col2" >183.000000</td>
#       <td id="T_46951_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_46951_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_46951_row3_col5" class="data row3 col5" >87.000000</td>
#       <td id="T_46951_row3_col6" class="data row3 col6" >126.000000</td>
#       <td id="T_46951_row3_col7" class="data row3 col7" >11.000000</td>
#       <td id="T_46951_row3_col8" class="data row3 col8" >127.000000</td>
#       <td id="T_46951_row3_col9" class="data row3 col9" >74.000000</td>
#       <td id="T_46951_row3_col10" class="data row3 col10" >2.000000</td>
#       <td id="T_46951_row3_col11" class="data row3 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46951_level2_row4" class="row_heading level2 row4" >average</th>
#       <td id="T_46951_row4_col0" class="data row4 col0" >44.000000</td>
#       <td id="T_46951_row4_col1" class="data row4 col1" >27.000000</td>
#       <td id="T_46951_row4_col2" class="data row4 col2" >183.000000</td>
#       <td id="T_46951_row4_col3" class="data row4 col3" >2.000000</td>
#       <td id="T_46951_row4_col4" class="data row4 col4" >5.000000</td>
#       <td id="T_46951_row4_col5" class="data row4 col5" >87.000000</td>
#       <td id="T_46951_row4_col6" class="data row4 col6" >126.000000</td>
#       <td id="T_46951_row4_col7" class="data row4 col7" >11.000000</td>
#       <td id="T_46951_row4_col8" class="data row4 col8" >127.000000</td>
#       <td id="T_46951_row4_col9" class="data row4 col9" >74.000000</td>
#       <td id="T_46951_row4_col10" class="data row4 col10" >2.000000</td>
#       <td id="T_46951_row4_col11" class="data row4 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46951_level2_row5" class="row_heading level2 row5" >weighted</th>
#       <td id="T_46951_row5_col0" class="data row5 col0" >44.000000</td>
#       <td id="T_46951_row5_col1" class="data row5 col1" >27.000000</td>
#       <td id="T_46951_row5_col2" class="data row5 col

# %%
tree_ranks_df.dropna(axis=1).loc[:, "15", :].style.background_gradient(cmap=cm, axis=0)
# Out:
# <style type="text/css">
# #T_09c56_row0_col0, #T_09c56_row0_col1, #T_09c56_row0_col2, #T_09c56_row0_col3, #T_09c56_row0_col4, #T_09c56_row0_col5, #T_09c56_row0_col6, #T_09c56_row0_col7, #T_09c56_row0_col8, #T_09c56_row0_col9, #T_09c56_row0_col10, #T_09c56_row0_col11, #T_09c56_row1_col0, #T_09c56_row1_col1, #T_09c56_row1_col2, #T_09c56_row1_col3, #T_09c56_row1_col4, #T_09c56_row1_col5, #T_09c56_row1_col6, #T_09c56_row1_col7, #T_09c56_row1_col8, #T_09c56_row1_col9, #T_09c56_row1_col10, #T_09c56_row1_col11, #T_09c56_row2_col0, #T_09c56_row2_col1, #T_09c56_row2_col2, #T_09c56_row2_col3, #T_09c56_row2_col4, #T_09c56_row2_col5, #T_09c56_row2_col6, #T_09c56_row2_col7, #T_09c56_row2_col8, #T_09c56_row2_col9, #T_09c56_row2_col10, #T_09c56_row2_col11 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09c56_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >EGFR-SLK</th>
#       <th class="col_heading level0 col1" >EGFR-LOK</th>
#       <th class="col_heading level0 col2" >EGFR-GAK</th>
#       <th class="col_heading level0 col3" >SLK-LOK</th>
#       <th class="col_heading level0 col4" >DRAK2-CaMKK2</th>
#       <th class="col_heading level0 col5" >ABL2-AurA</th>
#       <th class="col_heading level0 col6" >ABL1-GAK</th>
#       <th class="col_heading level0 col7" >GAK-DAPK3</th>
#       <th class="col_heading level0 col8" >AurC-KIT</th>
#       <th class="col_heading level0 col9" >KIT-AMPKa2</th>
#       <th class="col_heading level0 col10" >KIT-FMS</th>
#       <th class="col_heading level0 col11" >ABL1-BMPR1B</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subset</th>
#       <th class="index_name level1" >weighting</th>
#       <th class="index_name level2" >cmethod</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09c56_level0_row0" class="row_heading level0 row0" rowspan="3">dfg_in</th>
#       <th id="T_09c56_level1_row0" class="row_heading level1 row0" rowspan="3">15</th>
#       <th id="T_09c56_level2_row0" class="row_heading level2 row0" >ward</th>
#       <td id="T_09c56_row0_col0" class="data row0 col0" >44.000000</td>
#       <td id="T_09c56_row0_col1" class="data row0 col1" >27.000000</td>
#       <td id="T_09c56_row0_col2" class="data row0 col2" >183.000000</td>
#       <td id="T_09c56_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_09c56_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_09c56_row0_col5" class="data row0 col5" >87.000000</td>
#       <td id="T_09c56_row0_col6" class="data row0 col6" >126.000000</td>
#       <td id="T_09c56_row0_col7" class="data row0 col7" >11.000000</td>
#       <td id="T_09c56_row0_col8" class="data row0 col8" >127.000000</td>
#       <td id="T_09c56_row0_col9" class="data row0 col9" >74.000000</td>
#       <td id="T_09c56_row0_col10" class="data row0 col10" >2.000000</td>
#       <td id="T_09c56_row0_col11" class="data row0 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09c56_level2_row1" class="row_heading level2 row1" >average</th>
#       <td id="T_09c56_row1_col0" class="data row1 col0" >44.000000</td>
#       <td id="T_09c56_row1_col1" class="data row1 col1" >27.000000</td>
#       <td id="T_09c56_row1_col2" class="data row1 col2" >183.000000</td>
#       <td id="T_09c56_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_09c56_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_09c56_row1_col5" class="data row1 col5" >87.000000</td>
#       <td id="T_09c56_row1_col6" class="data row1 col6" >126.000000</td>
#       <td id="T_09c56_row1_col7" class="data row1 col7" >11.000000</td>
#       <td id="T_09c56_row1_col8" class="data row1 col8" >127.000000</td>
#       <td id="T_09c56_row1_col9" class="data row1 col9" >74.000000</td>
#       <td id="T_09c56_row1_col10" class="data row1 col10" >2.000000</td>
#       <td id="T_09c56_row1_col11" class="data row1 col11" >220.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09c56_level2_row2" class="row_heading level2 row2" >weighted</th>
#       <td id="T_09c56_row2_col0" class="data row2 col0" >44.000000</td>
#       <td id="T_09c56_row2_col1" class="data row2 col1" >27.000000</td>
#       <td id="T_09c56_row2_col2" class="data row2 col2" >183.000000</td>
#       <td id="T_09c56_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_09c56_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_09c56_row2_col5" class="data row2 col5" >87.000000</td>
#       <td id="T_09c56_row2_col6" class="data row2 col6" >126.000000</td>
#       <td id="T_09c56_row2_col7" class="data row2 col7" >11.000000</td>
#       <td id="T_09c56_row2_col8" class="data row2 col8" >127.000000</td>
#       <td id="T_09c56_row2_col9" class="data row2 col9" >74.000000</td>
#       <td id="T_09c56_row2_col10" class="data row2 col10" >2.000000</td>
#       <td id="T_09c56_row2_col11" class="data row2 col11" >220.000000</td>
#     </tr>
#   </tbody>
# </table>
