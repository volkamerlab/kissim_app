# %% [markdown]
# # Predict ligand profiling using sequence (pooled Karaman and Davis dataset)
#
# In order to assess the predictive power of `kissim`, we here choose a ligand-centric evaluation.
# We will compare if `kissim` can predict on- and off-targets determined in ligand profiling studies.
#
# - Kinase-kinase distance dataset (use KinMap kinase names): Select kinases from profiling dataset by query ligand
# - Kinase-ligand profiling dataset (use KinMap kinase names and PKIDB ligand names): Select kinases from distances dataset by the ligand's on-target
# - Merge both datasets and keep only kinases that have measurements in both datasets
# - Rank kinases by distances
# - Calculuate enrichment factors and enrichment plots
# - Calculate ROC curves

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown, HTML

from src import data, evaluation
from src.paths import PATH_RESULTS

# %%
HERE = Path(_dh[-1])  # noqa: F821
PATH_RANKS = PATH_RESULTS / "dfg_in/ranks"
PATH_RANKS.mkdir(exist_ok=True)
PATH_AUCS = PATH_RESULTS / "dfg_in/auc"
PATH_AUCS.mkdir(exist_ok=True)

# %%
plt.style.use("seaborn")

# %% [markdown]
# ## Define parameters

# %%
# The only global that can be changed in this notebook
LIGAND_PROFILING_METHOD = "karaman-davis"

# %%
KINASE_DISTANCES_METHOD = "klifs-pocket-sequence"
KINASE_ACTIVITY_CUTOFF = 100
KINASE_ACTIVITY_MAX = True
MIN_N_SHARED_KINASES = 10
MIN_N_SHARED_ACTIVE_KINASES = 3

# %% [markdown]
# ## Kinase-kinase distances dataset
#
# __Criteria__:
#
# - Filters out kinases whose names cannot be mapped to KinMap kinase names.

# %%
# Full dataset (reported only, not further used)
kinase_df = data.distances.load(
    KINASE_DISTANCES_METHOD, structure_kinase_mapping_by="minimum", kinmap_kinases=False
)
print(f"Kinase distance matrix shape: {kinase_df.shape}")
# Out:
# Kinase distance matrix shape: (521, 521)

# %%
# Reduced dataset
kinase_df = data.distances.load(
    KINASE_DISTANCES_METHOD, structure_kinase_mapping_by="minimum", kinmap_kinases=True
)
print(f"Kinase distance matrix shape: {kinase_df.shape}")
kinase_df.iloc[:5, :5]
# Out:
# Changed kinase names (unknown names may be discarded - see function docstring):
#     kinase.input                    kinase.kinmap
# 47        MSK2-b                           MSK2_b
# 49        MSK1-b                           MSK1_b
# 56        RSK1-b                           RSK1_b
# 57        RSK3-b                           RSK3_b
# 58        RSK2-b                           RSK2_b
# 59        RSK4-b                           RSK4_b
# 120        DCLK1                          DCAMKL1
# 121        DCLK3                          DCAMKL3
# 122        DCLK2                          DCAMKL2
# 149      Obscn-b                          Obscn_b
# 151       SPEG-b                           SPEG_b
# 282       GCN2-b                           GCN2_b
# 324       MAP3K8  unknown (ambiguous kinase name)
# 413       JAK1-b                           JAK1_b
# 414       JAK2-b                           JAK2_b
# 415       JAK3-b                           JAK3_b
# 417       TYK2-b                           TYK2_b
# 504        p110b          unknown (not in KinMap)
# 505        p110g          unknown (not in KinMap)
# 506        p110d          unknown (not in KinMap)
# 507        p110a          unknown (not in KinMap)
# 508       PIK3C3          unknown (not in KinMap)
# 509       PI4K2A          unknown (not in KinMap)
# 510        PI4KB          unknown (not in KinMap)
# 511       PI4K2B          unknown (not in KinMap)
# 512      PIK3C2G          unknown (not in KinMap)
# 513      PIK3C2A          unknown (not in KinMap)
# 514      PI4KAP2          unknown (not in KinMap)
# 515      PIK3C2B          unknown (not in KinMap)
# 516        PI4KA          unknown (not in KinMap)
# 517      CSNK2A3          unknown (not in KinMap)
# 518       Map4k2          unknown (not in KinMap)
# 520       PDPK2P          unknown (not in KinMap)
# Kinase distance matrix shape: (504, 504)
#            AKT1      AKT2      AKT3      CRIK     DMPK1
# AKT1   0.000000  0.129412  0.141176  0.611765  0.588235
# AKT2   0.129412  0.000000  0.105882  0.588235  0.552941
# AKT3   0.141176  0.105882  0.000000  0.611765  0.576471
# CRIK   0.611765  0.588235  0.611765  0.000000  0.364706
# DMPK1  0.588235  0.552941  0.576471  0.364706  0.000000

# %% [markdown]
# ## Kinase-ligand profiling dataset
#
# __Criteria__:
#
# - Load dataset with FDA-approved PKIDB ligands only.
# - Filters out ligands whose names cannot be mapped onto PKIDB ligand names.

# %%
# Full dataset (reported only, not further used)
profiling_df = data.profiling.load(LIGAND_PROFILING_METHOD)
print(f"Number of kinases (full dataset): {profiling_df.shape[0]}")
print(f"Number of ligands (full dataset): {profiling_df.shape[1]}")
# Out:
# No measurements                                                                 20611
# One measurement                                                                  6296
# Two identical measurements                                                       1291
# Two measurements <= or > cutoff 100; keep lower value                              30
# One measurement <=, one > cutoff 100 but difference <= 100; keep lower value        2
# One measurement <=, one > cutoff 100 but difference > 100; remove values           10
# dtype: int64
# Number of kinases (full dataset): 353
# Number of ligands (full dataset): 80

# %%
# Reduced dataset
profiling_df = data.profiling.load(LIGAND_PROFILING_METHOD, pkidb_ligands=True, fda_approved=True)
print(f"Number of kinases (FDA-approved PKIDB ligands only): {profiling_df.shape[0]}")
print(f"Number of ligands (FDA-approved PKIDB ligands only): {profiling_df.shape[1]}")
profiling_df.head()
# Out:
# Changed ligand names (unknown names may be discarded - see function docstring):
#            ligand.input            ligand.pkidb
# 0         Staurosporine  unknown (not in PKIDB)
# 1           JNJ-7706621  unknown (not in PKIDB)
# 2              MLN-8054  unknown (not in PKIDB)
# 3               PKC-412             Midostaurin
# 4              SU-14813  unknown (not in PKIDB)
# 5             SB-202190  unknown (not in PKIDB)
# 6             CP-724714  unknown (not in PKIDB)
# 7        VX-680/MK-0457  unknown (not in PKIDB)
# 9   Roscovitine/CYC-202  unknown (not in PKIDB)
# 10            SB-203580  unknown (not in PKIDB)
# 12            CP-690550             Tofacitinib
# 14              GW-2580  unknown (not in PKIDB)
# 16            GW-786034  unknown (not in PKIDB)
# 18               VX-745            Neflamapimod
# 19            SB-431542  unknown (not in PKIDB)
# 20              ZD-6474              Vandetanib
# 22         Flavopiridol  unknown (not in PKIDB)
# 24              MLN-518              Tandutinib
# 25            LY-333531           Ruboxistaurin
# 26              CI-1033              Canertinib
# 27              EKB-569               Pelitinib
# 28               PI-103  unknown (not in PKIDB)
# 29              PTK-787               Vatalanib
# Changed ligand names (unknown names may be discarded - see function docstring):
#          ligand.input            ligand.pkidb
# 0           TG-101348              Fedratinib
# 1           SB-203580  unknown (not in PKIDB)
# 3    CHIR-265/RAF-265  unknown (not in PKIDB)
# 4        AZD-1152HQPA  unknown (not in PKIDB)
# 5            MLN-8054  unknown (not in PKIDB)
# ..                ...                     ...
# 67          LY-333531           Ruboxistaurin
# 68            CI-1033              Canertinib
# 69  AZD-6244/ARRY-886  unknown (not in PKIDB)
# 70             PI-103  unknown (not in PKIDB)
# 71           AZD-2171               Cediranib
#
# [61 rows x 2 columns]
# No measurements                                                                 8964
# One measurement                                                                 2298
# Two identical measurements                                                       710
# Two measurements <= or > cutoff 100; keep lower value                             23
# One measurement <=, one > cutoff 100 but difference <= 100; keep lower value       1
# One measurement <=, one > cutoff 100 but difference > 100; remove values           6
# dtype: int64
# Number of kinases (FDA-approved PKIDB ligands only): 353
# Number of ligands (FDA-approved PKIDB ligands only): 34
#        Midostaurin  Dasatinib  Gefitinib  Tofacitinib  Imatinib  Lapatinib  \
# AAK1          48.0        NaN        NaN          NaN       NaN        NaN
# ABL1           NaN      0.046      480.0          NaN      12.0        NaN
# ABL2           NaN      0.170     1600.0          NaN      10.0        NaN
# ACK          120.0      5.600        NaN          NaN       NaN        NaN
# ACTR2          NaN    210.000        NaN          NaN       NaN        NaN
#
#        Sorafenib  Neflamapimod  Vandetanib  Sunitinib  ...  Crizotinib  \
# AAK1         NaN           NaN         NaN       11.0  ...      2300.0
# ABL1       680.0         730.0         NaN      150.0  ...       110.0
# ABL2      2900.0        1900.0        69.0     1000.0  ...       460.0
# ACK          NaN           NaN         NaN     8900.0  ...       760.0
# ACTR2        NaN           NaN         NaN        NaN  ...         NaN
#
#        Motesanib  Doramapimod  Enzastaurin  Lestaurtinib  Pazopanib  \
# AAK1         NaN          NaN       2700.0           3.1     2900.0
# ABL1      6700.0          NaN          NaN        1000.0      650.0
# ABL2      4500.0       1300.0          NaN        6500.0     3000.0
# ACK          NaN          NaN          NaN           6.6        NaN
# ACTR2        NaN          NaN          NaN        2500.0        NaN
#
#        Pictilisib  Bosutinib  Afatinib  Cediranib
# AAK1       9100.0   2300.000       NaN        NaN
# ABL1          NaN      0.057     570.0       78.0
# ABL2          NaN      1.500       NaN      730.0
# ACK           NaN     29.000       NaN        NaN
# ACTR2         NaN        NaN       NaN        NaN
#
# [5 rows x 34 columns]

# %%
profiling_df.count().sort_values().plot(kind="barh");

# %% [markdown]
# ## Ligands' on-targets dataset
#
# __Criteria__:
#
# - Filters out ligands that are not available in the PKIDB or have no targets in the PKIDB.
# - Filters out targets whose names cannot be mapped onto KinMap names

# %%
pd.set_option("max_colwidth", 100)
ligand_names = profiling_df.columns
ligand_targets = data.targets.pkidb(ligand_names, fda_approved=False)
ligand_targets
# Out:
# Changed kinase names (unknown names may be discarded - see function docstring):
#     kinase.input            kinase.kinmap
# 0            nan  unknown (not in KinMap)
# 3          EPHA2                    EphA2
# 5           YES1                      YES
# 7         PDGFRB                   PDGFRb
# 17         NTRK1                     TRKA
# 18         CSF1R                      FMS
# 19        PDGFRA                   PDGFRa
# 22        PDGFRB                   PDGFRb
# 24         ERBB2                    ErbB2
# 30        PDGFRB                   PDGFRb
# 35        MAPK14                     p38a
# 36         VEGFA  unknown (not in KinMap)
# 38          PTK6                      BRK
# 39           TEK                     TIE2
# 41        PDGFRB                   PDGFRb
# 47         CSF1R                      FMS
# 48        PDGFRA                   PDGFRa
# 50         NR1I2  unknown (not in KinMap)
# 52         PDGFD  unknown (not in KinMap)
# 53           nan  unknown (not in KinMap)
# 56         ERBB2                    ErbB2
# 69         CSF1R                      FMS
# 72         CSF1R                      FMS
# 74         ERBB2                    ErbB2
# 77        PDGFRA                   PDGFRa
# 78        PDGFRB                   PDGFRb
# 88        PDGFRA                   PDGFRa
# 89        PDGFRB                   PDGFRb
# 92        MAPK14                     p38a
# 93           nan  unknown (not in KinMap)
# 98        PDGFRA                   PDGFRa
# 99        PDGFRB                   PDGFRb
# 104       PIK3CA  unknown (not in KinMap)
# 105       PIK3CB  unknown (not in KinMap)
# 106       PIK3CD  unknown (not in KinMap)
# 107       PIK3CG  unknown (not in KinMap)
# 117       CAMK2G                   CaMK2g
# 119        ERBB2                    ErbB2
# 120        ERBB4                    ErbB4
#     ligand.input  \
# 0   Lestaurtinib
# 1     Tandutinib
# 2       Brivanib
# 3     Canertinib
# 4      Cediranib
# 5    Doramapimod
# 6      Erlotinib
# 7      Gefitinib
# 8   Neflamapimod
# 9     Crizotinib
# 10     Pelitinib
# 11     Nilotinib
# 12     Neratinib
# 13     Lapatinib
# 14   Quizartinib
# 15      Afatinib
# 16    Fedratinib
# 17      Axitinib
# 18     Linifanib
# 19     Vatalanib
# 20    Vandetanib
# 21   Tofacitinib
# 22     Masitinib
# 23     Motesanib
# 24      Imatinib
# 25     Sunitinib
# 26     Pazopanib
# 27     Dasatinib
# 28     Bosutinib
# 29     Sorafenib
#
#                                                        targets.pkidb  \
# 0                                                             [FLT3]
# 1                                                             [FLT3]
# 2                                                              [KDR]
# 3                                                             [EGFR]
# 4                                                              [KDR]
# 5                                                           [MAPK14]
# 6                                                             [EGFR]
# 7                                                             [EGFR]
# 8                                                           [MAPK14]
# 9                                                         [ALK, MET]
# 10                                                     [EGFR, ERBB2]
# 11                                                       [ABL1, KIT]
# 12                                                     [ERBB2, EGFR]
# 13                                                     [EGFR, ERBB2]
# 14                                                [FLT3, CSF1R, KIT]
# 15                                              [EGFR, ERBB2, ERBB4]
# 16                                                [JAK2, FLT3, BRD4]
# 17                                                 [FLT1, KDR, FLT4]
# 18                                                [FLT3, CSF1R, KDR]
# 19                                                 [FLT1, KDR, FLT4]
# 20                                            [EGFR, PTK6, TEK, RET]
# 21                                          [JAK1, JAK2, JAK3, TYK2]
# 22                        [KIT, PDGFRA, PDGFRB, FGFR1, FGFR2, FGFR3]
# 23                       [FLT1, KDR, FLT4, PDGFRA, PDGFRB, KIT, RET]
# 24              [KIT, RET, NTRK1, CSF1R, PDGFRA, DDR1, ABL1, PDGFRB]
# 25               [PDGFRB, FLT1, KIT, KDR, FLT4, FLT3, CSF1R, PDGFRA]
# 26         [FLT1, KDR, FLT4, PDGFRA, PDGFRB, KIT, FGFR3, ITK, FGFR1]
# 27             [ABL1, SRC, EPHA2, LCK, YES1, KIT, PDGFRB, ABL2, FYN]
# 28  [BCR, ABL1, LYN, HCK, SRC, CDK2, MAP2K1, MAP2K2, MAP3K2, CAMK2G]
# 29      [BRAF, RAF1, FLT4, KDR, FLT3, PDGFRB, KIT, FGFR1, RET, FLT1]
#
#                                                       targets.kinmap
# 0                                                             [FLT3]
# 1                                                             [FLT3]
# 2                                                              [KDR]
# 3                                                             [EGFR]
# 4                                                              [KDR]
# 5                                                             [p38a]
# 6                                                             [EGFR]
# 7                                                             [EGFR]
# 8                                                             [p38a]
# 9                                                         [ALK, MET]
# 10                                                     [EGFR, ErbB2]
# 11                                                       [ABL1, KIT]
# 12                                                     [ErbB2, EGFR]
# 13                                                     [EGFR, ErbB2]
# 14                                                  [FLT3, FMS, KIT]
# 15                                              [EGFR, ErbB2, ErbB4]
# 16                                                [JAK2, FLT3, BRD4]
# 17                                                 [FLT1, KDR, FLT4]
# 18                                                  [FLT3, FMS, KDR]
# 19                                                 [FLT1, KDR, FLT4]
# 20                                            [EGFR, BRK, TIE2, RET]
# 21                                          [JAK1, JAK2, JAK3, TYK2]
# 22                        [KIT, PDGFRa, PDGFRb, FGFR1, FGFR2, FGFR3]
# 23                       [FLT1, KDR, FLT4, PDGFRa, PDGFRb, KIT, RET]
# 24                 [KIT, RET, TRKA, FMS, PDGFRa, DDR1, ABL1, PDGFRb]
# 25                 [PDGFRb, FLT1, KIT, KDR, FLT4, FLT3, FMS, PDGFRa]
# 26         [FLT1, KDR, FLT4, PDGFRa, PDGFRb, KIT, FGFR3, ITK, FGFR1]
# 27              [ABL1, SRC, EphA2, LCK, YES, KIT, PDGFRb, ABL2, FYN]
# 28  [BCR, ABL1, LYN, HCK, SRC, CDK2, MAP2K1, MAP2K2, MAP3K2, CaMK2g]
# 29      [BRAF, RAF1, FLT4, KDR, FLT3, PDGFRb, KIT, FGFR1, RET, FLT1]

# %% [markdown]
# ### Ligand-kinase datasets
#
# We merge now profiling and kinase similarity information into one dataset per ligand-kinase pair (_ligand-kinase dataset_).
#
# We only keep ligand-kinase pairs that
# - have a minimum of `MIN_N_SHARED_KINASES` shared kinases
# - have a minimum of `MIN_N_SHARED_ACTIVE_KINASES` shared active kinases, while activity is defined <= `KINASE_ACTIVITY_CUTOFF`

# %% [markdown]
# Select ligand-kinase pairs with enough coverage.

# %%
ligand_kinase_pairs = (
    ligand_targets[["ligand.input", "targets.kinmap"]]
    .explode("targets.kinmap")
    .to_numpy()
    .tolist()
)

# %% [markdown]
# ## Evaluation metrics

# %%
evaluator = evaluation.LigandVsKinaseEvaluator(
    ligand_kinase_pairs,
    LIGAND_PROFILING_METHOD,
    KINASE_DISTANCES_METHOD,
    KINASE_ACTIVITY_CUTOFF,
    KINASE_ACTIVITY_MAX,
    MIN_N_SHARED_KINASES,
    MIN_N_SHARED_ACTIVE_KINASES,
)
# Out:
# Changed ligand names (unknown names may be discarded - see function docstring):
#            ligand.input            ligand.pkidb
# 0         Staurosporine  unknown (not in PKIDB)
# 1           JNJ-7706621  unknown (not in PKIDB)
# 2              MLN-8054  unknown (not in PKIDB)
# 3               PKC-412             Midostaurin
# 4              SU-14813  unknown (not in PKIDB)
# 5             SB-202190  unknown (not in PKIDB)
# 6             CP-724714  unknown (not in PKIDB)
# 7        VX-680/MK-0457  unknown (not in PKIDB)
# 9   Roscovitine/CYC-202  unknown (not in PKIDB)
# 10            SB-203580  unknown (not in PKIDB)
# 12            CP-690550             Tofacitinib
# 14              GW-2580  unknown (not in PKIDB)
# 16            GW-786034  unknown (not in PKIDB)
# 18               VX-745            Neflamapimod
# 19            SB-431542  unknown (not in PKIDB)
# 20              ZD-6474              Vandetanib
# 22         Flavopiridol  unknown (not in PKIDB)
# 24              MLN-518              Tandutinib
# 25            LY-333531           Ruboxistaurin
# 26              CI-1033              Canertinib
# 27              EKB-569               Pelitinib
# 28               PI-103  unknown (not in PKIDB)
# 29              PTK-787               Vatalanib
# Changed ligand names (unknown names may be discarded - see function docstring):
#          ligand.input            ligand.pkidb
# 0           TG-101348              Fedratinib
# 1           SB-203580  unknown (not in PKIDB)
# 3    CHIR-265/RAF-265  unknown (not in PKIDB)
# 4        AZD-1152HQPA  unknown (not in PKIDB)
# 5            MLN-8054  unknown (not in PKIDB)
# ..                ...                     ...
# 67          LY-333531           Ruboxistaurin
# 68            CI-1033              Canertinib
# 69  AZD-6244/ARRY-886  unknown (not in PKIDB)
# 70             PI-103  unknown (not in PKIDB)
# 71           AZD-2171               Cediranib
#
# [61 rows x 2 columns]
# No measurements                                                                 8964
# One measurement                                                                 2298
# Two identical measurements                                                       710
# Two measurements <= or > cutoff 100; keep lower value                             23
# One measurement <=, one > cutoff 100 but difference <= 100; keep lower value       1
# One measurement <=, one > cutoff 100 but difference > 100; remove values           6
# dtype: int64
# ERROR:root:'ErbB2 is not an active kinase in the ligand profiling dataset for Pelitinib'
# ERROR:root:'JAK2 is not part of the ligand profiling dataset for Fedratinib'
# ERROR:root:'Query kinase BRD4 is not part of dataset.'
# ERROR:root:'FLT4 is not an active kinase in the ligand profiling dataset for Axitinib'
# ERROR:root:'FLT4 is not an active kinase in the ligand profiling dataset for Vatalanib'
# ERROR:root:'BRK is not an active kinase in the ligand profiling dataset for Vandetanib'
# ERROR:root:'TIE2 is not an active kinase in the ligand profiling dataset for Vandetanib'
# ERROR:root:'JAK1 is not part of the ligand profiling dataset for Tofacitinib'
# ERROR:root:'JAK2 is not part of the ligand profiling dataset for Tofacitinib'
# ERROR:root:'JAK3 is not part of the ligand profiling dataset for Tofacitinib'
# ERROR:root:'TYK2 is not part of the ligand profiling dataset for Tofacitinib'
# ERROR:root:'FGFR1 is not part of the ligand profiling dataset for Masitinib'
# ERROR:root:'FGFR2 is not part of the ligand profiling dataset for Masitinib'
# ERROR:root:'FGFR3 is not part of the ligand profiling dataset for Masitinib'
# ERROR:root:'RET is not part of the ligand profiling dataset for Imatinib'
# ERROR:root:'TRKA is not part of the ligand profiling dataset for Imatinib'
# ERROR:root:'FGFR3 is not an active kinase in the ligand profiling dataset for Pazopanib'
# ERROR:root:'ITK is not part of the ligand profiling dataset for Pazopanib'
# ERROR:root:'FGFR1 is not an active kinase in the ligand profiling dataset for Pazopanib'
# ERROR:root:'Query kinase BCR is not part of dataset.'
# ERROR:root:'CDK2 is not part of the ligand profiling dataset for Bosutinib'
# ERROR:root:'CaMK2g is not an active kinase in the ligand profiling dataset for Bosutinib'
# ERROR:root:'BRAF is not an active kinase in the ligand profiling dataset for Sorafenib'
# ERROR:root:'RAF1 is not an active kinase in the ligand profiling dataset for Sorafenib'
# ERROR:root:'FGFR1 is not an active kinase in the ligand profiling dataset for Sorafenib'

# %%
print(f"Number of pairs: {len(evaluator.ligand_kinase_pairs)}")
print(f"Number of ligands: {len(set([i[0] for i in evaluator.ligand_kinase_pairs]))}")
# Out:
# Number of pairs: 112
# Number of ligands: 30

# %% [markdown]
# ### Ligand types

# %%
pkidb = data.ligands.pkidb()
ligands = pkidb.set_index("ID")["Type"][list(evaluator.data_dict.keys())].reset_index()
ligands
# Out:
#               ID Type
# 0   Lestaurtinib  nan
# 1     Tandutinib  nan
# 2       Brivanib  nan
# 3     Canertinib  nan
# 4      Cediranib  nan
# 5    Doramapimod    2
# 6      Erlotinib  1.5
# 7      Gefitinib  1.5
# 8   Neflamapimod  nan
# 9     Crizotinib    1
# 10     Pelitinib    1
# 11     Nilotinib    2
# 12     Neratinib  nan
# 13     Lapatinib  1.5
# 14   Quizartinib    2
# 15      Afatinib    1
# 16    Fedratinib  nan
# 17      Axitinib    2
# 18     Linifanib  nan
# 19     Vatalanib  nan
# 20    Vandetanib  1.5
# 21     Masitinib  nan
# 22     Motesanib    2
# 23      Imatinib    2
# 24     Sunitinib    1
# 25     Pazopanib    1
# 26     Dasatinib    1
# 27     Bosutinib    1
# 28     Sorafenib    2

# %% [markdown]
# ### Enrichment
#
# #### Enrichment factor
#
# An enrichment factor is calculated as follows:
#
# $EF_{x\%} = \frac{\frac{n_s}{n}}{\frac{N_s}{N}}$
#
# with
#
# - $N$   : Number of kinases in total
# - $N_s$ : Number of kinases in top x% of ranked kinases
# - $n$   : Number of active kinases in total
# - $n_s$ : Number of active kinases in top x% of ranked kinases

# %%
evaluator.plot_enrichment_factors()

# %% [markdown]
# #### Enrichment plots
#
# For an enrichment plot, the x and y values are calculated as follows:
#
# $x = \frac{N_s}{N}$, $y = \frac{n_s}{n}$
#
# with
#
# - $N$   : Number of kinases in total
# - $N_s$ : Number of kinases in top x% of ranked kinases
# - $n$   : Number of active kinases in total
# - $n_s$ : Number of active kinases in top x% of ranked kinases

# %%
evaluator.plot_enrichment()

# %% [markdown]
# ### ROC curves
#
# - $TPR = \frac{TP}{P} = \frac{TP}{TP + FN}$
# - $FPR = \frac{FP}{N} = \frac{FP}{FP + TN}$

# %%
auc_dict = evaluator.plot_roc_curves(
    HERE / "../../notebooks/figures/profiling_roc_dfg_in_sequence.pdf"
)
auc_list = list(auc_dict.values())

# %%
# Save AUC values to file
pd.DataFrame(
    [entry[0].split("-") + [entry[1]] for entry in auc_dict.items()],
    columns=["ligand", "kinase", "auc"],
).to_csv(PATH_AUCS / f"auc_{KINASE_DISTANCES_METHOD}_vs_{LIGAND_PROFILING_METHOD}.csv")

# %%
print(f"Number of pairs: {len(auc_list)}")
# Out:
# Number of pairs: 83

# %%
np.mean(auc_list)
# Out:
# 0.7766306400326934

# %%
np.std(auc_list)
# Out:
# 0.15317963878794044

# %% [markdown]
# #### Selected ligand ROC curves

# %%
selected_ligands = ["Erlotinib", "Imatinib", "Bosutinib", "Doramapimod"]

# %%
# Select pairs based on selected ligands (in given order!!)
# Looks a bit complicated but necessary to keep ligand order!
ligand_kinase_pairs_df = pd.DataFrame(ligand_kinase_pairs, columns=["ligand", "kinase"])
ligand_kinase_pairs_selected = []
for selected_ligand in selected_ligands:
    ligand_kinase_pairs_selected.append(
        ligand_kinase_pairs_df.groupby("ligand").get_group(selected_ligand)
    )
ligand_kinase_pairs_selected = pd.concat(ligand_kinase_pairs_selected).values.tolist()

# %%
evaluator_selected = evaluation.LigandVsKinaseEvaluator(
    ligand_kinase_pairs_selected,
    LIGAND_PROFILING_METHOD,
    KINASE_DISTANCES_METHOD,
    KINASE_ACTIVITY_CUTOFF,
    KINASE_ACTIVITY_MAX,
    MIN_N_SHARED_KINASES,
    MIN_N_SHARED_ACTIVE_KINASES,
)
# Out:
# WARNING:src.data.ligands:Changed ligand names (unknown names may be discarded - see function docstring):
#            ligand.input            ligand.pkidb
# 0         Staurosporine  unknown (not in PKIDB)
# 1           JNJ-7706621  unknown (not in PKIDB)
# 2              MLN-8054  unknown (not in PKIDB)
# 3               PKC-412             Midostaurin
# 4              SU-14813  unknown (not in PKIDB)
# 5             SB-202190  unknown (not in PKIDB)
# 6             CP-724714  unknown (not in PKIDB)
# 7        VX-680/MK-0457  unknown (not in PKIDB)
# 9   Roscovitine/CYC-202  unknown (not in PKIDB)
# 10            SB-203580  unknown (not in PKIDB)
# 12            CP-690550             Tofacitinib
# 14              GW-2580  unknown (not in PKIDB)
# 16            GW-786034  unknown (not in PKIDB)
# 18               VX-745            Neflamapimod
# 19            SB-431542  unknown (not in PKIDB)
# 20              ZD-6474              Vandetanib
# 22         Flavopiridol  unknown (not in PKIDB)
# 24              MLN-518              Tandutinib
# 25            LY-333531           Ruboxistaurin
# 26              CI-1033              Canertinib
# 27              EKB-569               Pelitinib
# 28               PI-103  unknown (not in PKIDB)
# 29              PTK-787               Vatalanib
# WARNING:src.data.ligands:Changed ligand names (unknown names may be discarded - see function docstring):
#          ligand.input            ligand.pkidb
# 0           TG-101348              Fedratinib
# 1           SB-203580  unknown (not in PKIDB)
# 3    CHIR-265/RAF-265  unknown (not in PKIDB)
# 4        AZD-1152HQPA  unknown (not in PKIDB)
# 5            MLN-8054  unknown (not in PKIDB)
# ..                ...                     ...
# 67          LY-333531           Ruboxistaurin
# 68            CI-1033              Canertinib
# 69  AZD-6244/ARRY-886  unknown (not in PKIDB)
# 70             PI-103  unknown (not in PKIDB)
# 71           AZD-2171               Cediranib
#
# [61 rows x 2 columns]
# No measurements                                                                 8964
# One measurement                                                                 2298
# Two identical measurements                                                       710
# Two measurements <= or > cutoff 100; keep lower value                             23
# One measurement <=, one > cutoff 100 but difference <= 100; keep lower value       1
# One measurement <=, one > cutoff 100 but difference > 100; remove values           6
# dtype: int64
# ERROR:root:'RET is not part of the ligand profiling dataset for Imatinib'
# ERROR:root:'TRKA is not part of the ligand profiling dataset for Imatinib'
# ERROR:root:'Query kinase BCR is not part of dataset.'
# ERROR:root:'CDK2 is not part of the ligand profiling dataset for Bosutinib'
# ERROR:root:'CaMK2g is not an active kinase in the ligand profiling dataset for Bosutinib'

# %%
evaluator_selected.plot_roc_curves(
    HERE / "../../notebooks/figures/profiling_roc_dfg_in_selected_sequence.png"
);

# %% [markdown]
# ### In detail: Look at ranks!

# %%
from opencadd.databases.klifs import setup_remote

# %%
def show_ranking(evaluator, kinase, ligand):
    session = setup_remote()
    ranking = evaluator.data_dict[ligand][kinase].data
    kinase_groups = session.kinases.by_kinase_name(ranking.index.to_list(), species="Human")[
        ["kinase.klifs_name", "kinase.group"]
    ].set_index("kinase.klifs_name")
    ranking = pd.merge(ranking, kinase_groups, left_index=True, right_index=True)
    return ranking

# %%
pairs = [
    ["EGFR", "Erlotinib"],
    ["ABL1", "Imatinib"],
    ["ABL1", "Bosutinib"],
    ["p38a", "Doramapimod"],
]

# %%
for kinase, ligand in pairs:
    display(Markdown(f"#### {ligand}"))
    try:
        ranks = show_ranking(evaluator_selected, kinase, ligand)
        display(HTML(ranks.to_html()))
        display(HTML(ranks[ranks["karaman-davis.active"]].to_html()))
        ranks[ranks["karaman-davis.active"]].to_csv(
            PATH_RANKS / f"ranks_{KINASE_DISTANCES_METHOD}_{ligand}_{kinase}.csv"
        )
    except KeyError:
        print(f"Data unavailable for {kinase} and {ligand}")
# Out:
# #### Erlotinib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>karaman-davis.measure</th>
#       <th>karaman-davis.active</th>
#       <th>karaman-davis.rank1</th>
#       <th>karaman-davis.rank2</th>
#       <th>klifs-pocket-sequence.measure</th>
#       <th>klifs-pocket-sequence.rank1</th>
#       <th>klifs-pocket-sequence.rank2</th>
#       <th>kinase.group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EGFR</th>
#       <td>0.67</td>
#       <td>True</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>ErbB2</th>
#       <td>2900.00</td>
#       <td>False</td>
#       <td>65.0</td>
#       <td>64.0</td>
#       <td>0.105882</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>ErbB4</th>
#       <td>230.00</td>
#       <td>False</td>
#       <td>9.0</td>
#       <td>8.0</td>
#       <td>0.164706</td>
#       <td>3.0</td>
#       <td>3.0</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>ErbB3</th>
#       <td>1100.00</td>
#       <td>False</td>
#       <td>32.0</td>
#       <td>31.0</td>
#       <td>0.411765</td>
#       <td>4.0</td>
#       <td>4.0</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>ABL2</th>
#       <td>200.00</td>
#       <td>False</td>
#       <td>8.0</td>
#       <td>7.0</td>
#       <td>0.447059</td>
#       <td>7.5</td>
#       <td>5.0</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>RET</th>
#       <td>1300.00</td>
#       <td>False</td>
#       <td>40.5</td>
#       <td>39.5</td>
#       <td>0.458824</td>
#       <td>10.0</td>
#       <td>6.5</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>FLT3</th>
#       <td>1200.00</td>
#       <td>False</td>
#       <td>36.0</td>
#       <td>35.0</td>
#       <td>0.458824</td>
#       <td>10.0</td>
#       <td>6.5</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>EphB1</th>
#       <td>1100.00</td>
#       <td>False</td>
#       <td>32.0</td>
#       <td>31.0</td>
#       <td>0.470588</td>
#       <td>13.5</td>
#       <td>8.5</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>FRK</th>
#       <td>2000.00</td>
#       <td>False</td>
#       <td>52.5</td>
#       <td>51.5</td>
#       <td>0.470588</td>
#       <td>13.5</td>
#       <td>8.5</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>EphA8</th>
#       <td>940.00</td>
#       <td>False</td>
#       <td>26.0</td>
#       <td>25.0</td>
#       <td>0.482353</td>
#       <td>18.0</td>
#       <td>10.0</td>
#       <td>TK</td>
#     </tr>
#     <tr>
#       <th>Eph