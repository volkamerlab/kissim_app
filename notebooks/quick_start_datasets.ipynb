# %% [markdown]
# # Quick start on how to access different datasets
#
# This notebook demonstrates how to use the `src.data` module to quickly and easily load different datasets on ligands, kinases, profiling, distances and target datasets.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

from IPython.display import display, HTML
from opencadd.databases import klifs

from src.data import ligands, kinases, profiling, distances, targets

# %%
HERE = Path(_dh[-1])  # noqa: F821
DATA = HERE / "../../data"
RESULTS = HERE / "../../results"

# %% [markdown]
# ## Ligand datasets
#
# Get kinase-binding ligand details.

# %% [markdown]
# ### PKIDB

# %%
dataset = ligands.pkidb()
print(f"Number of ligands: {dataset.shape[0]}")
dataset.head()
# Out:
# Number of ligands: 260
#   BrandName               Applicants      CHEMBL_ID  \
# 0                 Incyte Corporation  CHEMBL2216863
# 1                             Pfizer    CHEMBL13608
# 2                             Pfizer  CHEMBL2103874
# 3            Nanjing Yoko Biomedical  CHEMBL2180602
# 4                    TP Therapeutics  CHEMBL4298138
#
#                                     Canonical_Smiles            Chirality  \
# 0  Cc1csc2n1c(=O)c(c(n2)[C@H](C)Nc3c4c([nH]cn4)nc...  Single Stereoisomer
# 1  Cc1c([nH]c(c1C(=O)NCCN2CCCC2)C)/C=C\3/c4cc(ccc...     Achiral Molecule
# 2  CNS(=O)(=O)C[C@H]1CC[C@@H](CC1)N(c2ncnc3c2cc[n...  Single Stereoisomer
# 3  CCN(CC)CCNC(=O)c1c([nH]c\2c1CCC/C2=C/3\c4cc(cc...     Achiral Molecule
# 4  CC1CNC(=O)C2=C3N=C(C=CN3N=C2)NC(C4=C(O1)C=CC(=...  Single Stereoisomer
#
#   First_Approval Phase SC_Patent                             Synonyms  \
# 0            nan   0.0      None            [DEZAPELISIB, INCB040093]
# 1            nan   0.0      None              [PHA-291639, TOCERANIB]
# 2            nan   0.0      None     [JAKI, OCLACITINIB, PF-03394197]
# 3            nan   1.0      None  [SIM 010603, SIM-010603, TAFETINIB]
# 4            nan   1.0      None  [REPOTRECTINIB, TPX-0005, TRX-0005]
#
#   Withdrawn  ...  NRB   TPSA LogP  RoF Melting point             Targets  \
# 0            ...  4.0  100.9  3.7  0.0                             [nan]
# 1            ...  5.0   77.2  3.1  0.0                             [KIT]
# 2            ...  5.0   91.0  1.5  0.0                [JAK1, JAK2, JAK3]
# 3            ...  6.0   77.2  3.7  0.0                 [KDR, FLT4, FLT1]
# 4            ...  0.0   80.6  2.6  0.0                             [nan]
#
#   Kinase families FDA_approved             ID  \
# 0                                 Dezapelisib
# 1             KIT                   Toceranib
# 2             Tyr                 Oclacitinib
# 3             Tyr                   Tafetinib
# 4                               Repotrectinib
#
#                                                ROMol
# 0  <img data-content="rdkit/molecule" src="data:i...
# 1  <img data-content="rdkit/molecule" src="data:i...
# 2  <img data-content="rdkit/molecule" src="data:i...
# 3  <img data-content="rdkit/molecule" src="data:i...
# 4  <img data-content="rdkit/molecule" src="data:i...
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Kinase datasets
#
# Get kinase details.

# %% [markdown]
# ### KinMap

# %%
dataset = kinases.kinmap()
print(f"Number of kinases: {dataset.shape[0]}")
dataset.head()
# Out:
# Number of kinases: 536
#     xName Manning Name HGNC Name  \
# 0    ABL1          ABL      ABL1
# 1     ACK          ACK      TNK2
# 2   ACTR2        ACTR2    ACVR2A
# 3  ACTR2B       ACTR2B    ACVR2B
# 4   ADCK4        ADCK4     ADCK4
#
#                                          Kinase Name     Group Family  \
# 0                       Tyrosine-protein kinase ABL1        TK    Abl
# 1                           Activated CDC42 kinase 1        TK    Ack
# 2                           Activin receptor type-2A       TKL   STKR
# 3                           Activin receptor type-2B       TKL   STKR
# 4  Uncharacterized aarF domain-containing protein...  Atypical   ABC1
#
#   SubFamily UniprotID
# 0       NaN    P00519
# 1       NaN    Q07912
# 2     STKR2    P27037
# 3     STKR2    Q13705
# 4    ABC1-A    Q96D53

# %% [markdown]
# ### KLIFS

# %%
klifs_session = klifs.setup_remote()
dataset = klifs_session.kinases.all_kinases()
print(f"Number of kinases: {dataset.shape[0]}")
dataset.head()
# Out:
# Number of kinases: 1127
#    kinase.klifs_id kinase.hgnc_name            kinase.full_name species.klifs
# 0              813    4921509C19Rik  RIKEN cDNA 4921509C19 gene         Mouse
# 1              815    4921509C19Rik  RIKEN cDNA 4921509C19 gene         Mouse
# 2              814    4921509C19Rik  RIKEN cDNA 4921509C19 gene         Mouse
# 3              531             Aak1     AP2 associated kinase 1         Mouse
# 4              277             AAK1     AP2 associated kinase 1         Human

# %% [markdown]
# ## Profiling datasets
#
# Get kinase-ligand bioactivities.

# %% [markdown]
# ### Karaman
#
# Bioactivity measure: $K_D$ [nM]

# %%
dataset = profiling.karaman()
print(f"Number of kinases: {dataset.shape[0]}")
print(f"Number of ligands: {dataset.shape[1]}")
display(HTML(dataset.head().to_html()))
dataset.count().sort_values().plot(kind="barh", figsize=(5, 6));
# Out:
# Number of kinases: 268
# Number of ligands: 30
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Staurosporine</th>
#       <th>JNJ-7706621</th>
#       <th>MLN-8054</th>
#       <th>PKC-412</th>
#       <th>SU-14813</th>
#       <th>SB-202190</th>
#       <th>CP-724714</th>
#       <th>VX-680/MK-0457</th>
#       <th>Dasatinib</th>
#       <th>Roscovitine/CYC-202</th>
#       <th>SB-203580</th>
#       <th>Gefitinib</th>
#       <th>CP-690550</th>
#       <th>Imatinib</th>
#       <th>GW-2580</th>
#       <th>Lapatinib</th>
#       <th>GW-786034</th>
#       <th>Sorafenib</th>
#       <th>VX-745</th>
#       <th>SB-431542</th>
#       <th>ZD-6474</th>
#       <th>Sunitinib</th>
#       <th>Flavopiridol</th>
#       <th>Erlotinib</th>
#       <th>MLN-518</th>
#       <th>LY-333531</th>
#       <th>CI-1033</th>
#       <th>EKB-569</th>
#       <th>PI-103</th>
#       <th>PTK-787</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAK1</th>
#       <td>1.2</td>
#       <td>200.0</td>
#       <td>NaN</td>
#       <td>48.0</td>
#       <td>66.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>290.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2900.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>11.0</td>
#       <td>5300.0</td>
#       <td>1200.0</td>
#       <td>NaN</td>
#       <td>900.0</td>
#       <td>NaN</td>
#       <td>3500.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>ABL1</th>
#       <td>290.0</td>
#       <td>1200.0</td>
#       <td>820.0</td>
#       <td>NaN</td>
#       <td>1500.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>13.0</td>
#       <td>0.53</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>12.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1700.0</td>
#       <td>680.0</td>
#       <td>730.0</td>
#       <td>NaN</td>
#       <td>270.0</td>
#       <td>830.0</td>
#       <td>NaN</td>
#       <td>310.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1400.0</td>
#       <td>560.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>ABL2</th>
#       <td>110.0</td>
#       <td>NaN</td>
#       <td>3300.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.0</td>
#       <td>0.17</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>10.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3000.0</td>
#       <td>2900.0</td>
#       <td>1900.0</td>
#       <td>NaN</td>
#       <td>69.0</td>
#       <td>1000.0</td>
#       <td>NaN</td>
#       <td>200.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>870.0</td>
#       <td>370.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>ALK2</th>
#       <td>470.0</td>
#       <td>5900.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1900.0</td>
#       <td>620.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>150.0</td>
#       <td>NaN</td>
#       <td>1900.0</td>
#       <td>NaN</td>
#       <td>2500.0</td>
#       <td>NaN</td>
#       <td>1700.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>ALK4</th>
#       <td>680.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>950.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>330.00</td>
#       <td>NaN</td>
#       <td>3000.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>190.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Davis
#
# Bioactivity measure: $K_D$ [nM]

# %%
dataset = profiling.davis()
print(f"Number of kinases: {dataset.shape[0]}")
print(f"Number of ligands: {dataset.shape[1]}")
display(HTML(dataset.head().to_html()))
dataset.count().sort_values().plot(kind="barh", figsize=(5, 12));
# Out:
# Number of kinases: 350
# Number of ligands: 72
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>TG-101348</th>
#       <th>SB-203580</th>
#       <th>Nilotinib</th>
#       <th>CHIR-265/RAF-265</th>
#       <th>AZD-1152HQPA</th>
#       <th>MLN-8054</th>
#       <th>AG-013736</th>
#       <th>CHIR-258/TKI-258</th>
#       <th>PKC-412</th>
#       <th>SU-14813</th>
#       <th>JNJ-28312141</th>
#       <th>PP-242</th>
#       <th>AC220</th>
#       <th>ABT-869</th>
#       <th>HKI-272</th>
#       <th>SGX-523</th>
#       <th>EXEL-2880/GSK-1363089</th>
#       <th>AB-1010</th>
#       <th>BMS-540215</th>
#       <th>PTK-787</th>
#       <th>Crizotinib</th>
#       <th>A-674563</th>
#       <th>Gefitinib</th>
#       <th>VX-680/MK-0457</th>
#       <th>CP-690550</th>
#       <th>PHA-665752</th>
#       <th>AMG-706</th>
#       <th>CI-1040</th>
#       <th>MLN-120B</th>
#       <th>Staurosporine</th>
#       <th>BMS-387032/SNS-032</th>
#       <th>BIRB-796</th>
#       <th>GSK-1838705A</th>
#       <th>BI-2536</th>
#       <th>GW-2580</th>
#       <th>R547</th>
#       <th>GSK-690693</th>
#       <th>GDC-0879</th>
#       <th>Lapatinib</th>
#       <th>PLX-4720</th>
#       <th>Dasatinib</th>
#       <th>R406</th>
#       <th>INCB18424</th>
#       <th>LY-317615</th>
#       <th>KW-2449</th>
#       <th>AT-7519</th>
#       <th>BIBF-1120 (derivative)</th>
#       <th>VX-745</th>
#       <th>Ki-20227</th>
#       <th>BMS-345541</th>
#       <th>Vandetanib</th>
#       <th>Sorafenib</th>
#       <th>CEP-701</th>
#       <th>GSK-461364A</th>
#       <th>PD-173955</th>
#       <th>Pazopanib</th>
#       <th>AST-487</th>
#       <th>GDC-0941</th>
#       <th>TG-100-115</th>
#       <th>MLN-518</th>
#       <th>Sunitinib</th>
#       <th>Flavopiridol</th>
#       <th>Erlotinib</th>
#       <th>TAE-684</th>
#       <th>Imatinib</th>
#       <th>SKI-606</th>
#       <th>BIBW-2992</th>
#       <th>LY-333531</th>
#       <th>CI-1033</th>
#       <th>AZD-6244/ARRY-886</th>
#       <th>PI-103</th>
#       <th>AZD-2171</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAK1</th>
#       <td>35.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3000.0</td>
#       <td>NaN</td>
#       <td>1200.0</td>
#       <td>170.0</td>
#       <td>48.0</td>
#       <td>66.0</td>
#       <td>520.0</td>
#       <td>1600.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2300.0</td>
#       <td>43.0</td>
#       <td>NaN</td>
#       <td>290.0</td>
#       <td>NaN</td>
#       <td>320.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.2</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2800.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>410.0</td>
#       <td>120.0</td>
#       <td>2700.0</td>
#       <td>48.0</td>
#       <td>NaN</td>
#       <td>63.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3.1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2900.0</td>
#       <td>NaN</td>
#       <td>9100.0</td>
#       <td>870.0</td>
#       <td>NaN</td>
#       <td>11.0</td>
#       <td>5300.0</td>
#       <td>1200.0</td>
#       <td>470.0</td>
#       <td>NaN</td>
#       <td>2300.000</td>
#       <td>NaN</td>
#       <td>900.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>ABL1</th>
#       <td>44.0</td>
#       <td>NaN</td>
#       <td>13.0</td>
#       <td>3600.0</td>
#       <td>5500.0</td>
#       <td>890.0</td>
#       <td>36.0</td>
#       <td>54.0</td>
#       <td>NaN</td>
#       <td>620.0</td>
#       <td>390.0</td>
#       <td>69.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>56.0</td>
#       <td>55.0</td>
#       <td>640.0</td>
#       <td>NaN</td>
#       <td>110.0</td>
#       <td>NaN</td>
#       <td>480.0</td>
#       <td>7.5</td>
#       <td>NaN</td>
#       <td>8200.0</td>
#       <td>6700.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>22.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3500.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2300.0</td>
#       <td>0.046</td>
#       <td>340.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>75.0</td>
#       <td>NaN</td>
#       <td>64.0</td>
#       <td>NaN</td>
#       <td>320.0</td>
#       <td>NaN</td>
#       <td>16.0</td>
#       <td>1400.0</td>
#       <td>1000.0</td>
#       <td>NaN</td>
#       <td>0.58</td>
#       <td>650.0</td>
#       <td>13.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>150.0</td>
#       <td>1500.0</td>
#       <td>76.0</td>
#       <td>170.0</td>
#       <td>21.0</td>
#       <td>0.057</td>
#       <td>570.0</td>
#       <td>NaN</td>
#       <td>30.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>78.0</td>
#     </tr>
#     <tr>
#       <th>ABL2</th>
#       <td>570.0</td>
#       <td>NaN</td>
#       <td>26.0</td>
#       <td>1900.0</td>
#       <td>NaN</td>
#       <td>3300.0</td>
#       <td>70.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5300.0</td>
#       <td>1200.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>27.0</td>
#       <td>110.0</td>
#       <td>1800.0</td>
#       <td>NaN</td>
#       <td>460.0</td>
#       <td>NaN</td>
#       <td>1600.0</td>
#       <td>4.0</td>
#       <td>NaN</td>
#       <td>6900.0</td>
#       <td>4500.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>110.0</td>
#       <td>NaN</td>
#       <td>1300.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2700.0</td>
#       <td>0.170</td>
#       <td>720.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>250.0</td>
#       <td>NaN</td>
#       <td>2000.0</td>
#       <td>1900.0</td>
#       <td>950.0</td>
#       <td>NaN</td>
#       <td>69.0</td>
#       <td>2900.0</td>
#       <td>6500.0</td>
#       <td>NaN</td>
#       <td>0.69</td>
#       <td>3000.0</td>
#       <td>3.4</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1000.0</td>
#       <td>NaN</td>
#       <td>200.0</td>
#       <td>380.0</td>
#       <td>10.0</td>
#       <td>1.500</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>870.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>730.0</td>
#     </tr>
#     <tr>
#       <th>ALK2</th>
#       <td>150.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>390.0</td>
#       <td>4.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>440.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1900.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>470.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>620.000</td>
#       <td>4800.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>140.0</td>
#       <td>NaN</td>
#       <td>600.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>150.0</td>
#       <td>NaN</td>
#       <td>75.0</td>
#       <td>NaN</td>
#       <td>160.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2500.0</td>
#       <td>NaN</td>
#       <td>1900.0</td>
#       <td>NaN</td>
#       <td>29.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1700.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3400.0</td>
#     </tr>
#     <tr>
#       <th>ALK4</th>
#       <td>6700.0</td>
#       <td>3000.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>

# %% [markdown]
# ### PKIS2
#
# Bioactivity measure:
# > Percentage of the kinase that remains bound to the immobilized inhibitor relative to a DMSO control (% control). We then converted these numbers into percent inhibition (%Inh)
# >
# > $\%Inh = 100 - \%control$
#
# https://doi.org/10.1371/journal.pone.0181585
#
# We will call this measure here $\%displ$ (percent of kinase displaced)

# %%
dataset = profiling.pkis2(kinmap_kinases=True)
print(f"Number of kinases: {dataset.shape[0]}")
print(f"Number of ligands: {dataset.shape[1]}")
print(f"Minimum value: {dataset.min().min()}")
print(f"Maximum value: {dataset.max().max()}")
dataset.head()
# Out:
# /home/dominique/.local/miniconda/envs/kissim/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:308: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Changed kinase names (unknown names may be discarded - see function docstring):
#     kinase.input            kinase.kinmap
# 3          ACVR1                     ALK2
# 4         ACVR1B                     ALK4
# 5         ACVR2A                    ACTR2
# 6         ACVR2B                   ACTR2B
# 7         ACVRL1                     ALK1
# ..           ...                      ...
# 376         WNK1                     Wnk1
# 377         WNK2                     Wnk2
# 378         WNK3                     Wnk3
# 379         WNK4                     Wnk4
# 385         YSK4  unknown (not in KinMap)
#
# [162 rows x 2 columns]
# Number of kinases: 341
# Number of ligands: 645
# Minimum value: 0.0
# Maximum value: 100.0
# compound  UNC10225469A  UNC10225012A  UNC10225159A  UNC10225310A  \
# AAK1              14.0           0.0           0.0           0.0
# ABL1              28.0          99.7           8.0          28.0
# ABL2               5.0          81.0           5.0         100.0
# ALK2               0.0           7.0          18.0          17.0
# ALK4               0.0           9.0           0.0          15.0
#
# compound  UNC10225187A  UNC10225062A  UNC10225296A  UNC10225430A  \
# AAK1              26.0           0.0          10.0           0.0
# ABL1              49.0          33.0         100.0          21.0
# ABL2               3.0          12.0         100.0          14.0
# ALK2              10.0           7.0          99.4          11.0
# ALK4              85.0           0.0          79.0           0.0
#
# compound  UNC10225266A  UNC10225324A  ...  UNC10225504A  UNC10243858A  \
# AAK1               0.0           0.0  ...           6.0          30.0
# ABL1              19.0           0.0  ...           0.0          38.0
# ABL2               3.0          14.0  ...           5.0           0.0
# ALK2               0.0          51.0  ...           0.0           1.0
# ALK4             100.0           0.0  ...           0.0           0.0
#
# compound  UNC10243859A  UNC10243860A  UNC10243861A  UNC10243862A  \
# AAK1              18.0           0.0          16.0           0.0
# ABL1               0.0           0.0           0.0          34.0
# ABL2               2.0          17.0           0.0           0.0
# ALK2               0.0           0.0           3.0           0.0
# ALK4               0.0           0.0           0.0           4.0
#
# compound  UNC10243863A  UNC10243880A  UNC10243881A  UNC10244034A
# AAK1               0.0          61.0          25.0           0.0
# ABL1               7.0          13.0           0.0           0.0
# ABL2              19.0          47.0          17.0           0.0
# ALK2              37.0           0.0          14.0           0.0
# ALK4               0.0           8.0           0.0           0.0
#
# [5 rows x 645 columns]

# %%
ax = (dataset > 0).sum().plot(kind="hist")
ax.set_xlabel(r"Number of $\%displ > 0$ values in full dataset");

# %%
ax = dataset.plot(kind="kde", legend=None, xlim=(0, 100))
ax.set_xlabel(r"$\%displ$ distribution per ligand");

# %% [markdown]
# ## Kinase-kinase distances datasets
#
# Get kinase-kinase distances.

# %% [markdown]
# ### KiSSim

# %%
dataset = distances.kissim()
print(f"Kinase distance matrix dimensions: {dataset.shape}")
dataset.iloc[:5, :5]
# Out:
# Kinase distance matrix dimensions: (292, 292)
# kinase2      AAK1      ABL1      ABL2       ACK     ACTR2
# kinase1
# AAK1     0.000000  0.239739  0.246362  0.246718  0.261379
# ABL1     0.239739  0.000000  0.032393  0.137668  0.280255
# ABL2     0.246362  0.032393  0.000000  0.148981  0.294966
# ACK      0.246718  0.137668  0.148981  0.000000  0.293667
# ACTR2    0.261379  0.280255  0.294966  0.293667  0.000000

# %% [markdown]
# ## Target datasets
#
# Get targets for input ligands.

# %% [markdown]
# ### PKIDB

# %%
ligand_names = ["Erlotinib", "Lapatinib", "Imatinib"]
targets.pkidb(ligand_names)
# Out:
# Changed kinase names (unknown names may be discarded - see function docstring):
#    kinase.input            kinase.kinmap
# 1         NR1I2  unknown (not in KinMap)
# 3         ERBB2                    ErbB2
# 6         NTRK1                     TRKA
# 7         CSF1R                      FMS
# 8        PDGFRA                   PDGFRa
# 11       PDGFRB                   PDGFRb
#   ligand.input                                      targets.pkidb  \
# 0    Erlotinib                                             [EGFR]
# 1    Lapatinib                                      [EGFR, ERBB2]
# 2     Imatinib  [KIT, RET, NTRK1, CSF1R, PDGFRA, DDR1, ABL1, P...
#
#                                       targets.kinmap
# 0                                             [EGFR]
# 1                                      [EGFR, ErbB2]
# 2  [KIT, RET, TRKA, FMS, PDGFRa, DDR1, ABL1, PDGFRb]
