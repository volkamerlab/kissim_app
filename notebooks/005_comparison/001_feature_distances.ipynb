# %% [markdown]
# # Feature distances
#
# We check the per-feature distributions (e.g. size distances or hinge region distances) based on all pairwise fingerprint feature distances. Which features show the most/fewest variations?

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
from kissim.comparison import FeatureDistancesGenerator

from src.paths import PATH_RESULTS

# %%
HERE = Path(_dh[-1])  # noqa: F821
RESULTS = PATH_RESULTS

# %%
plt.style.use("seaborn")

# %%
def plot_feature_distances(dfg_conformation, results_path=RESULTS):
    # Load feature distances
    feature_distances_generator = FeatureDistancesGenerator.from_csv(
        results_path / f"{dfg_conformation}/feature_distances.csv.bz2"
    )
    print("Number of distances:", len(feature_distances_generator.data))
    columns = [f"d{i}" for i in range(1, len(feature_distances_generator.distances[0]) + 1)]
    distances = pd.DataFrame(feature_distances_generator.distances, columns=columns)

    # Feature distribution
    distances.plot(kind="box", whis=[1, 99])

# %% [raw]
# plot_feature_distances("all")

# %%
plot_feature_distances("dfg_in")
# Out:
# Number of distances: 8452216

# %%
plot_feature_distances("dfg_out")
# Out:
# Number of distances: 82215

# %%
feature_distances_generator = FeatureDistancesGenerator.from_csv(
    RESULTS / "dfg_in/feature_distances.csv.bz2"
)
print("Number of distances:", len(feature_distances_generator.data))
columns = [f"d{i}" for i in range(1, len(feature_distances_generator.distances[0]) + 1)]
distances = pd.DataFrame(feature_distances_generator.distances, columns=columns)
# Out:
# Number of distances: 8452216

# %%
distances.describe()
# Out:
#                  d1            d2            d3            d4            d5  \
# count  8.452216e+06  8.452216e+06  8.452216e+06  8.452216e+06  8.452216e+06
# mean   2.172460e-01  1.356315e-01  1.761950e-01  1.168521e-01  1.251180e-01
# std    5.771133e-02  3.585017e-02  4.327573e-02  2.997471e-02  4.452858e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.904762e-01  1.193416e-01  1.582278e-01  1.011905e-01  9.638554e-02
# 50%    2.202381e-01  1.382114e-01  1.785714e-01  1.202532e-01  1.219512e-01
# 75%    2.500000e-01  1.547619e-01  2.023810e-01  1.352941e-01  1.547619e-01
# max    4.382716e-01  2.727273e-01  3.928571e-01  2.261905e-01  3.373494e-01
#
#                  d6            d7            d8            d9           d10  \
# count  8.452216e+06  8.452216e+06  8.452216e+06  8.452216e+06  8.337486e+06
# mean   2.233188e-01  1.409826e-01  2.291246e-01  1.470616e-02  1.415496e-02
# std    7.895082e-02  4.319116e-02  5.120315e-02  5.369304e-03  4.807673e-03
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.785714e-01  1.133333e-01  1.951220e-01  1.155264e-02  1.061291e-02
# 50%    2.142857e-01  1.369863e-01  2.289157e-01  1.370213e-02  1.371704e-02
# 75%    2.592593e-01  1.621622e-01  2.625000e-01  1.625967e-02  1.739124e-02
# max    5.952381e-01  4.461538e-01  5.357143e-01  5.006819e-02  5.110683e-02
#
#                 d11           d12           d13           d14           d15
# count  8.452216e+06  8.452216e+06  8.452216e+06  8.452216e+06  8.452216e+06
# mean   1.518503e-02  1.558006e-02  6.420263e-02  5.926575e-02  5.842772e-02
# std    5.436096e-03  5.253781e-03  3.768561e-02  3.258952e-02  4.475551e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.175112e-02  1.214686e-02  3.663924e-02  3.638540e-02  2.871099e-02
# 50%    1.433404e-02  1.493389e-02  5.597315e-02  5.389172e-02  4.270213e-02
# 75%    1.729239e-02  1.804818e-02  8.377097e-02  7.520501e-02  6.827619e-02
# max    4.940873e-02  4.353341e-02  4.120824e-01  4.435665e-01  3.547086e-01
